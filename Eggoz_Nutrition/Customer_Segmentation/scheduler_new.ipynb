# %% [markdown]
# Scheduler Function for sending transformed excel sheets to recipients

# %%
#!pip install schedule
#!pip install snowflake-connector-python

# %%
import snowflake.connector
import pandas as pd
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import schedule
import time

def fetch_transform_send():
    # Snowflake credentials
    username = 'Harshiteggoz'
    password = 'Eggoz@123'
    account = 'wt08714.ap-south-1.aws'
    warehouse = 'COMPUTE_WH'
    database = 'EGGOZDB'
    schema = 'MAPLEMONK'
    
    # Email credentials 
    sender_email = 'abhishektiwari.nssc@gmail.com'
    app_password = 'rpax rxpp mpws wzvb' 
    receiver_email = 'abhitiwari.sirka2001@kgpian.iitkgp.ac.in'
    
    # Connecting to Snowflake
    conn = snowflake.connector.connect(
        user=username,
        password=password,
        account=account,
        warehouse=warehouse,
        database=database,
        schema=schema
    )
    
    # Execute Snowflake SQL Queries
    cur = conn.cursor()
    cur.execute("USE EGGOZDB")  # Corrected the order of execution
    
    query = f"SHOW TABLES IN SCHEMA {schema}"
    cur.execute(query)
    tables_df = pd.read_sql_query(query, conn)

    sql_query = "SELECT * FROM your_table"  # Replace 'your_table' with the actual table name
    df = pd.read_sql_query(sql_query, conn)

    # Create Excel attachment
    excel_attachment = MIMEText(df.to_excel(index=False), 'excel')
    excel_attachment.add_header('Content-Disposition', 'attachment', filename='transformed_data.xlsx')
    
    # Create email message
    email_message = MIMEMultipart()
    email_message['From'] = sender_email
    email_message['To'] = receiver_email
    email_message['Subject'] = 'Transformed Data'
    email_message.attach(excel_attachment)
    
    # Send email using SMTP
    with smtplib.SMTP('smtp.gmail.com', 587) as server:
        server.starttls()
        server.login(sender_email, app_password)
        server.sendmail(sender_email, receiver_email, email_message.as_string())

    conn.close()

# Schedule the message to be sent every second (for testing purposes)
schedule.every(1).second.do(fetch_transform_send)

# Run the scheduler loop
while True:
    schedule.run_pending()
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# c:\Users\User\Downloads\Eggoz\scheduler_new.ipynb Cell 4 line 6
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#W3sZmlsZQ%3D%3D?line=63'>64</a> query = f"SHOW TABLES IN SCHEMA MAPPLEMONK"
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#W3sZmlsZQ%3D%3D?line=64'>65</a> # Schedule the message to be sent every second (for testing purposes)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#W3sZmlsZQ%3D%3D?line=65'>66</a> schedule.every(1).second.do(fetch_transform_send(query))
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#W3sZmlsZQ%3D%3D?line=67'>68</a> '''# Run the scheduler loop
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#W3sZmlsZQ%3D%3D?line=68'>69</a> while True:
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#W3sZmlsZQ%3D%3D?line=69'>70</a>     schedule.run_pending()
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#W3sZmlsZQ%3D%3D?line=70'>71</a>     time.sleep(1)'''
#
# c:\Users\User\Downloads\Eggoz\scheduler_new.ipynb Cell 4 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#W3sZmlsZQ%3D%3D?line=34'>35</a> cur.execute("USE EGGOZDB")
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#W3sZmlsZQ%3D%3D?line=35'>36</a> # Corrected the order of execution
# ---> <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#W3sZmlsZQ%3D%3D?line=38'>39</a> cur.execute(query)
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#W3sZmlsZQ%3D%3D?line=39'>40</a> tables_df = pd.read_sql_query(query, conn)
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#W3sZmlsZQ%3D%3D?line=41'>42</a> sql_query = "SELECT * FROM your_table"  # Replace 'your_table' with the actual table name
#
# File ~\AppData\Roaming\Python\Python310\site-packages\snowflake\connector\cursor.py:920, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, _skip_upload_on_content_match, file_stream, num_statements)
#     916     is_integrity_error = (
#     917         code == "100072"
#     918     )  # NULL result in a non-nullable column
#     919     error_class = IntegrityError if is_integrity_error else ProgrammingError
# --> 920     Error.errorhandler_wrapper(self.connection, self, error_class, errvalue)
#     921 return self
#
# File ~\AppData\Roaming\Python\Python310\site-packages\snowflake\connector\errors.py:290, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     267 @staticmethod
#     268 def errorhandler_wrapper(
#     269     connection: SnowflakeConnection | None,
#    (...)
#     272     error_value: dict[str, Any],
#     273 ) -> None:
#     274     """Error handler wrapper that calls the errorhandler method.
#     275
#     276     Args:
#    (...)
#     287         exception to the first handler in that order.
#     288     """
# --> 290     handed_over = Error.hand_to_other_handler(
#     291         connection,
#     292         cursor,
#     293         error_class,
#     294         error_value,
#     295     )
#     296     if not handed_over:
#     297         raise Error.errorhandler_make_exception(
#     298             error_class,
#     299             error_value,
#     300         )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\snowflake\connector\errors.py:345, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     343 if cursor is not None:
#     344     cursor.messages.append((error_class, error_value))
# --> 345     cursor.errorhandler(connection, cursor, error_class, error_value)
#     346     return True
#     347 elif connection is not None:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\snowflake\connector\errors.py:221, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     219 errno = error_value.get("errno")
#     220 done_format_msg = error_value.get("done_format_msg")
# --> 221 raise error_class(
#     222     msg=error_value.get("msg"),
#     223     errno=None if errno is None else int(errno),
#     224     sqlstate=error_value.get("sqlstate"),
#     225     sfqid=error_value.get("sfqid"),
#     226     query=error_value.get("query"),
#     227     done_format_msg=(
#     228         None if done_format_msg is None else bool(done_format_msg)
#     229     ),
#     230     connection=connection,
#     231     cursor=cursor,
#     232 )
#
# ProgrammingError: 002043 (02000): SQL compilation error:
# Object does not exist, or operation cannot be performed.

# %%
# Snowflake credentials
username = 'Harshiteggoz'
password = 'Eggoz@123'
account = 'wt08714.ap-south-1.aws'
warehouse = 'COMPUTE_WH'
database = 'EGGOZDB'
schema = 'MAPLEMONK'

# %%
    
# Email credentials 
sender_email = 'abhishektiwari.nssc@gmail.com'
app_password = 'rpax rxpp mpws wzvb' 
receiver_email = 'abhitiwari.sirka2001@kgpian.iitkgp.ac.in'

# %%
# Connecting to Snowflake
conn = snowflake.connector.connect(
        user=username,
        password=password,
        account=account,
        warehouse=warehouse,
        database=database,
        schema=schema
    )
    
    # Execute Snowflake SQL Queries
cur = conn.cursor()
cur.execute("USE EGGOZDB")  # Corrected the order of execution
    
query = f"SHOW TABLES IN SCHEMA {schema}"
cur.execute(query)
tables_df = pd.read_sql_query(query, conn)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16120\11636311.py:17: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   tables_df = pd.read_sql_query(query, conn)

# %%
tables_df
# Out:
#                            created_on  \
# 0    2023-11-27 15:01:21.952000+00:00
# 1    2023-12-07 04:10:46.337000+00:00
# 2    2022-11-11 09:06:55.496000+00:00
# 3    2023-12-07 10:15:40.830000+00:00
# 4    2023-12-07 10:15:43.133000+00:00
# ...                               ...
# 2548 2023-04-13 04:00:25.620000+00:00
# 2549 2023-10-05 04:13:55.008000+00:00
# 2550 2023-04-13 04:00:30.837000+00:00
# 2551 2023-09-27 16:17:56.310000+00:00
# 2552 2023-09-06 10:14:16.771000+00:00
#
#                                                    name database_name  \
# 0                           ACTIVATIONS_REPORT_AND_SALE       EGGOZDB
# 1                                      ACTIVE_RETAILERS       EGGOZDB
# 2                                  AGEING_SUMMARY_TABLE       EGGOZDB
# 3                                             ALL_BILLS       EGGOZDB
# 4                                         ALL_BILLS_SKU       EGGOZDB
# ...                                                 ...           ...
# 2548                  _AIRBYTE_TMP_ZXU_MY_SQL_BASE_CITY       EGGOZDB
# 2549           _AIRBYTE_TMP_ZYT_EPM_KPI_TRACKER_TARGETS       EGGOZDB
# 2550  _AIRBYTE_TMP_ZYY_MY_SQL_SALESCHAIN_SALESPERSON...       EGGOZDB
# 2551  _AIRBYTE_TMP_ZYY_REGION_WISE_PROCUREMENT_MASTE...       EGGOZDB
# 2552           _AIRBYTE_TMP_ZZS_EPM_KPI_TRACKER_TARGETS       EGGOZDB
#
#      schema_name   kind comment cluster_by    rows     bytes         owner  \
# 0      MAPLEMONK  TABLE                     339613   5726208  ACCOUNTADMIN
# 1      MAPLEMONK  TABLE                     263838  10141184  ACCOUNTADMIN
# 2      MAPLEMONK  TABLE                      27525    307712  ACCOUNTADMIN
# 3      MAPLEMONK  TABLE                     220216  16783360  ACCOUNTADMIN
# 4      MAPLEMONK  TABLE                     425753  12562944  ACCOUNTADMIN
# ...          ...    ...     ...        ...     ...       ...           ...
# 2548   MAPLEMONK  TABLE                         27      6656  ACCOUNTADMIN
# 2549   MAPLEMONK  TABLE                          0         0  ACCOUNTADMIN
# 2550   MAPLEMONK  TABLE                        341     20480  ACCOUNTADMIN
# 2551   MAPLEMONK  TABLE                          0         0  ACCOUNTADMIN
# 2552   MAPLEMONK  TABLE                          1      6144  ACCOUNTADMIN
#
#      retention_time automatic_clustering change_tracking is_external  \
# 0                 1                  OFF             OFF           N
# 1                 1                  OFF             OFF           N
# 2                 1                  OFF             OFF           N
# 3                 1                  OFF             OFF           N
# 4                 1                  OFF             OFF           N
# ...             ...                  ...             ...         ...
# 2548              0                  OFF             OFF           N
# 2549              0                  OFF             OFF           N
# 2550              0                  OFF             OFF           N
# 2551              0                  OFF             OFF           N
# 2552              0                  OFF             OFF           N
#
#      enable_schema_evolution owner_role_type is_event budget
# 0                          N            ROLE        N   None
# 1                          N            ROLE        N   None
# 2                          N            ROLE        N   None
# 3                          N            ROLE        N   None
# 4                          N            ROLE        N   None
# ...                      ...             ...      ...    ...
# 2548                       N            ROLE        N   None
# 2549                       N            ROLE        N   None
# 2550                       N            ROLE        N   None
# 2551                       N            ROLE        N   None
# 2552                       N            ROLE        N   None
#
# [2553 rows x 18 columns]

# %%
 # Create email message
email_message = MIMEMultipart()
email_message['From'] = sender_email
email_message['To'] = receiver_email
email_message['Subject'] = 'Tables in Schema'

# %%
    # Add tables information to the email body
email_message.attach(MIMEText(tables_df.to_string(index=False), 'plain'))
    
    # Send email using SMTP
with smtplib.SMTP('smtp.gmail.com', 587) as server:
        server.starttls()
        server.login(sender_email, app_password)
        server.sendmail(sender_email, receiver_email, email_message.as_string())

conn.close()

# %%
import snowflake.connector
import pandas as pd
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import schedule
import time

def fetch_transform_send():
    # Snowflake credentials
    username = 'Harshiteggoz'
    password = 'Eggoz@123'
    account = 'wt08714.ap-south-1.aws'
    warehouse = 'COMPUTE_WH'
    database = 'EGGOZDB'
    schema = 'MAPLEMONK'
    
    # Email credentials 
    sender_email = 'abhishektiwari.nssc@gmail.com'
    app_password = 'rpax rxpp mpws wzvb' 
    receiver_email = 'abhitiwari.sirka2001@kgpian.iitkgp.ac.in'
    
    # Connecting to Snowflake
    conn = snowflake.connector.connect(
        user=username,
        password=password,
        account=account,
        warehouse=warehouse,
        database=database,
        schema=schema
    )
    
    # Execute Snowflake SQL Queries
    cur = conn.cursor()
    cur.execute("USE EGGOZDB")
    
    # Replace 'your_table' with the actual table name
    query = f"SHOW TABLES IN SCHEMA {schema}"
    result_df = pd.read_sql_query(query, conn)

    # Create Excel attachment
    excel_attachment = MIMEText(result_df.to_excel(index=False), 'excel')
    excel_attachment.add_header('Content-Disposition', 'attachment', filename='transformed_data.xlsx')
    
    # Create email message
    email_message = MIMEMultipart()
    email_message['From'] = sender_email
    email_message['To'] = receiver_email
    email_message['Subject'] = 'Transformed Data'
    email_message.attach(excel_attachment)
    
    # Send email using SMTP
    with smtplib.SMTP('smtp.gmail.com', 587) as server:
        server.starttls()
        server.login(sender_email, app_password)
        server.sendmail(sender_email, receiver_email, email_message.as_string())

    conn.close()

# Schedule the message to be sent every second (for testing purposes)
schedule.every(1).second.do(fetch_transform_send)

# Run the scheduler loop
while True:
    schedule.run_pending()
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# c:\Users\User\Downloads\Eggoz\scheduler_new.ipynb Cell 11 line 6
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#X11sZmlsZQ%3D%3D?line=62'>63</a> # Run the scheduler loop
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#X11sZmlsZQ%3D%3D?line=63'>64</a> while True:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#X11sZmlsZQ%3D%3D?line=64'>65</a>     schedule.run_pending()
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#X11sZmlsZQ%3D%3D?line=65'>66</a>     time.sleep(1)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:822, in run_pending()
#     818 def run_pending() -> None:
#     819     """Calls :meth:`run_pending <Scheduler.run_pending>` on the
#     820     :data:`default scheduler instance <default_scheduler>`.
#     821     """
# --> 822     default_scheduler.run_pending()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:100, in Scheduler.run_pending(self)
#      98 runnable_jobs = (job for job in self.jobs if job.should_run)
#      99 for job in sorted(runnable_jobs):
# --> 100     self._run_job(job)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:172, in Scheduler._run_job(self, job)
#     171 def _run_job(self, job: "Job") -> None:
# --> 172     ret = job.run()
#     173     if isinstance(ret, CancelJob) or ret is CancelJob:
#     174         self.cancel_job(job)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:693, in Job.run(self)
#     690     return CancelJob
#     692 logger.debug("Running job %s", self)
# --> 693 ret = self.job_func()
#     694 self.last_run = datetime.datetime.now()
#     695 self._schedule_next_run()
#
# c:\Users\User\Downloads\Eggoz\scheduler_new.ipynb Cell 11 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#X11sZmlsZQ%3D%3D?line=35'>36</a> sql_query = "USE EGGOZDB"
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#X11sZmlsZQ%3D%3D?line=36'>37</a> cur = conn.cursor()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#X11sZmlsZQ%3D%3D?line=37'>38</a> cur.execute(query)
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#X11sZmlsZQ%3D%3D?line=39'>40</a> query = f"SHOW TABLES IN SCHEMA {schema}"
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#X11sZmlsZQ%3D%3D?line=40'>41</a> cur.execute(query)
#
# UnboundLocalError: local variable 'query' referenced before assignment

# %%
# correct code
import snowflake.connector
import pandas as pd
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import schedule
import time

# Snowflake credentials
username = 'Harshiteggoz'
password = 'Eggoz@123'
account = 'wt08714.ap-south-1.aws'
warehouse = 'COMPUTE_WH'
database = 'EGGOZDB'
schema = 'MAPLEMONK'

# Email credentials 
sender_email = 'abhishektiwari.nssc@gmail.com'
app_password = 'rpax rxpp mpws wzvb' 
receiver_email = 'abhitiwari.sirka2001@kgpian.iitkgp.ac.in'

# Connecting to Snowflake
conn = snowflake.connector.connect(
    user=username,
    password=password,
    account=account,
    warehouse=warehouse,
    database=database,
    schema=schema
)

# Execute Snowflake SQL Queries
cur = conn.cursor()
cur.execute(f"USE {database}.{schema}")

# Replace 'your_table' with the actual table name
query = f"SHOW TABLES IN SCHEMA {schema}"
result_df = pd.read_sql_query(query, conn)



# Save DataFrame to an Excel file
excel_file_path = 'transformed_data.csv'
result_df.to_csv(excel_file_path, index=False)

# Create Excel attachment
with open(excel_file_path, 'rb') as file:
    excel_attachment = MIMEText(file.read(), 'base64', 'utf-8')
    excel_attachment.add_header('Content-Disposition', 'attachment', filename='transformed_data.csv')

# Create email message
email_message = MIMEMultipart()
email_message['From'] = sender_email
email_message['To'] = receiver_email
email_message['Subject'] = 'Transformed Data'
email_message.attach(excel_attachment)

# Send email using SMTP
with smtplib.SMTP('smtp.gmail.com', 587) as server:
    server.starttls()
    server.login(sender_email, app_password)
    server.sendmail(sender_email, receiver_email, email_message.as_string())

conn.close()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16120\2608292472.py:39: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result_df = pd.read_sql_query(query, conn)

# %% [markdown]
# Current working cell

# %%
import pandas as pd

# %%
# !pip install apscheduler
# Out:
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\User\\AppData\\Roaming\\Python\\Python310\\site-packages\\apscheduler\\events.py'
# Check the permissions.
#
#
# [notice] A new release of pip is available: 23.0.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting apscheduler
#   Downloading APScheduler-3.10.4-py3-none-any.whl (59 kB)
#      ---------------------------------------- 0.0/59.3 kB ? eta -:--:--
#      ---------------------------------- ----- 51.2/59.3 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 59.3/59.3 kB 450.1 kB/s eta 0:00:00
# Requirement already satisfied: six>=1.4.0 in c:\users\user\appdata\roaming\python\python310\site-packages (from apscheduler) (1.16.0)
# Collecting tzlocal!=3.*,>=2.0
#   Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: pytz in c:\users\user\appdata\roaming\python\python310\site-packages (from apscheduler) (2022.7.1)
# Requirement already satisfied: tzdata in c:\users\user\appdata\roaming\python\python310\site-packages (from tzlocal!=3.*,>=2.0->apscheduler) (2023.3)
# Installing collected packages: tzlocal, apscheduler
# Defaulting to user installation because normal site-packages is not writeable
# Collecting apscheduler
#   Using cached APScheduler-3.10.4-py3-none-any.whl (59 kB)
# Requirement already satisfied: six>=1.4.0 in c:\users\user\appdata\roaming\python\python310\site-packages (from apscheduler) (1.16.0)
# Requirement already satisfied: pytz in c:\users\user\appdata\roaming\python\python310\site-packages (from apscheduler) (2022.7.1)
# Collecting tzlocal!=3.*,>=2.0
#   Using cached tzlocal-5.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: tzdata in c:\users\user\appdata\roaming\python\python310\site-packages (from tzlocal!=3.*,>=2.0->apscheduler) (2023.3)
# Installing collected packages: tzlocal, apscheduler
# Successfully installed apscheduler-3.10.4 tzlocal-5.2
# [notice] A new release of pip is available: 23.0.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import snowflake.connector
import pandas as pd
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import schedule
import time
from apscheduler.schedulers.blocking import BlockingScheduler

# Snowflake credentials
username = 'Harshiteggoz'
password = 'Eggoz@123'
account = 'wt08714.ap-south-1.aws'
warehouse = 'COMPUTE_WH'
database = 'EGGOZDB'
schema = 'MAPLEMONK'

# Connecting to Snowflake
conn = snowflake.connector.connect(
    user=username,
    password=password,
    account=account,
    warehouse=warehouse,
    database=database,
    schema=schema
)
# Email credentials 
sender_email = 'abhishektiwari.nssc@gmail.com'
app_password = 'rpax rxpp mpws wzvb' 
receiver_email = 'abhitiwari.sirka2001@kgpian.iitkgp.ac.in'
query=None
def transform(query):
    # Execute Snowflake SQL Queries
    # Connecting to Snowflake
    conn = snowflake.connector.connect(
        user=username,
        password=password,
        account=account,
        warehouse=warehouse,
        database=database,
        schema=schema
    )
    cur = conn.cursor()
    cur.execute(f"USE {database}.{schema}")


    result_df = pd.read_sql_query(query, conn)
    return result_df


def fetch_transform_send():

    # Replace 'your_table' with the actual table name
    query = f"SHOW TABLES IN SCHEMA {schema}"
    result_df = transform(query)

    # Save DataFrame to an Excel file
    excel_file_path = 'transformed_data.csv'
    result_df.to_csv(excel_file_path, index=False)

    # Create Excel attachment
    with open(excel_file_path, 'rb') as file:
        excel_attachment = MIMEText(file.read(), 'base64', 'utf-8')
        excel_attachment.add_header('Content-Disposition', 'attachment', filename='transformed_data.csv')

    # Create email message
    email_message = MIMEMultipart()
    email_message['From'] = sender_email
    email_message['To'] = receiver_email
    email_message['Subject'] = 'Transformed Data'
    email_message.attach(excel_attachment)

    # Send email using SMTP
    with smtplib.SMTP('smtp.gmail.com', 587) as server:
        server.starttls()
        server.login(sender_email, app_password)
        server.sendmail(sender_email, receiver_email, email_message.as_string())

    conn.close()

# Schedule the message to be sent every hour
schedule.every().minute.do(fetch_transform_send)
# Out:
# Every 1 minute do fetch_transform_send() (last run: [never], next run: 2023-12-10 10:21:34)

# %%
# Run the scheduler loop
while True:
    schedule.run_pending()
    time.sleep(60)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10800\4224181887.py:47: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result_df = pd.read_sql_query(query, conn)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Run the scheduler loop
#       2 while True:
# ----> 3     schedule.run_pending()
#       4     time.sleep(60)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:822, in run_pending()
#     818 def run_pending() -> None:
#     819     """Calls :meth:`run_pending <Scheduler.run_pending>` on the
#     820     :data:`default scheduler instance <default_scheduler>`.
#     821     """
# --> 822     default_scheduler.run_pending()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:100, in Scheduler.run_pending(self)
#      98 runnable_jobs = (job for job in self.jobs if job.should_run)
#      99 for job in sorted(runnable_jobs):
# --> 100     self._run_job(job)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:172, in Scheduler._run_job(self, job)
#     171 def _run_job(self, job: "Job") -> None:
# --> 172     ret = job.run()
#     173     if isinstance(ret, CancelJob) or ret is CancelJob:
#     174         self.cancel_job(job)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:693, in Job.run(self)
#     690     return CancelJob
#     692 logger.debug("Running job %s", self)
# --> 693 ret = self.job_func()
#     694 self.last_run = datetime.datetime.now()
#     695 self._schedule_next_run()
#
# Cell In[1], line 55, in fetch_transform_send()
#      51 def fetch_transform_send():
#      52
#      53     # Replace 'your_table' with the actual table name
#      54     query = f"SHOW TABLES IN SCHEMA {schema}"
# ---> 55     result_df = transform(query)
#      57     # Save DataFrame to an Excel file
#      58     excel_file_path = 'transformed_data.csv'
#
# Cell In[1], line 47, in transform(query)
#      43 cur = conn.cursor()
#      44 cur.execute(f"USE {database}.{schema}")
# ---> 47 result_df = pd.read_sql_query(query, conn)
#      48 return result_df
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\sql.py:397, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     339 """
#     340 Read SQL query into a DataFrame.
#     341
#    (...)
#     394 parameter will be converted to UTC.
#     395 """
#     396 pandas_sql = pandasSQL_builder(con)
# --> 397 return pandas_sql.read_query(
#     398     sql,
#     399     index_col=index_col,
#     400     params=params,
#     401     coerce_float=coerce_float,
#     402     parse_dates=parse_dates,
#     403     chunksize=chunksize,
#     404     dtype=dtype,
#     405 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\sql.py:2078, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#    2066 def read_query(
#    2067     self,
#    2068     sql,
#    (...)
#    2074     dtype: DtypeArg | None = None,
#    2075 ) -> DataFrame | Iterator[DataFrame]:
#    2077     args = _convert_params(sql, params)
# -> 2078     cursor = self.execute(*args)
#    2079     columns = [col_desc[0] for col_desc in cursor.description]
#    2081     if chunksize is not None:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\sql.py:2018, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2016 cur = self.con.cursor()
#    2017 try:
# -> 2018     cur.execute(*args, **kwargs)
#    2019     return cur
#    2020 except Exception as exc:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\snowflake\connector\cursor.py:899, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, _skip_upload_on_content_match, file_stream, num_statements)
#     893         self._total_rowcount = (
#     894             ret["data"]["total"]
#     895             if "data" in ret and "total" in ret["data"]
#     896             else -1
#     897         )
#     898         return data
# --> 899     self._init_result_and_meta(data)
#     900 else:
#     901     self._total_rowcount = (
#     902         ret["data"]["total"] if "data" in ret and "total" in ret["data"] else -1
#     903     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\snowflake\connector\cursor.py:966, in SnowflakeCursor._init_result_and_meta(self, data)
#     960     self._total_rowcount = data["total"]
#     962 self._description: list[ResultMetadata] = [
#     963     ResultMetadata.from_column(col) for col in data["rowtype"]
#     964 ]
# --> 966 result_chunks = create_batches_from_response(
#     967     self, self._query_result_format, data, self._description
#     968 )
#     970 if not (is_dml or self.is_file_transfer):
#     971     logger.info(
#     972         "Number of results in first chunk: %s", result_chunks[0].rowcount
#     973     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\snowflake\connector\result_batch.py:128, in create_batches_from_response(cursor, _format, data, schema)
#     123         python_method = cursor._connection.converter.to_python_method(
#     124             type_name, col
#     125         )
#     126         return type_name, python_method
# --> 128     column_converters = [col_to_converter(c) for c in rowtypes]
#     129 else:
#     130     rowset_b64 = data.get("rowsetBase64")
#
# File ~\AppData\Roaming\Python\Python310\site-packages\snowflake\connector\result_batch.py:128, in <listcomp>(.0)
#     123         python_method = cursor._connection.converter.to_python_method(
#     124             type_name, col
#     125         )
#     126         return type_name, python_method
# --> 128     column_converters = [col_to_converter(c) for c in rowtypes]
#     129 else:
#     130     rowset_b64 = data.get("rowsetBase64")
#
# File ~\AppData\Roaming\Python\Python310\site-packages\snowflake\connector\result_batch.py:123, in create_batches_from_response.<locals>.col_to_converter(col)
#     121 def col_to_converter(col: dict[str, Any]) -> tuple[str, SnowflakeConverterType]:
#     122     type_name = col["type"].upper()
# --> 123     python_method = cursor._connection.converter.to_python_method(
#     124         type_name, col
#     125     )
#     126     return type_name, python_method
#
# File ~\AppData\Roaming\Python\Python310\site-packages\snowflake\connector\converter.py:171, in SnowflakeConverter.to_python_method(self, type_name, column)
#     169 for conv in converters:
#     170     try:
# --> 171         return getattr(self, conv)(ctx)
#     172     except AttributeError:
#     173         pass
#
# File ~\AppData\Roaming\Python\Python310\site-packages\snowflake\connector\converter_issue23517.py:42, in SnowflakeConverterIssue23517._TIMESTAMP_LTZ_to_python(self, ctx)
#      41 def _TIMESTAMP_LTZ_to_python(self, ctx):
# ---> 42     tzinfo = self._get_session_tz()
#      43     scale = ctx["scale"]
#      45     def conv(value: str) -> datetime:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\snowflake\connector\converter.py:247, in SnowflakeConverter._get_session_tz(self)
#     245     if not tz:
#     246         tz = "UTC"
# --> 247     return pytz.timezone(tz)
#     248 except pytz.exceptions.UnknownTimeZoneError:
#     249     logger.warning("converting to tzinfo failed")
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pytz\__init__.py:181, in timezone(zone)
#     179 zone = _case_insensitive_zone_lookup(_unmunge_zone(zone))
#     180 if zone not in _tzinfo_cache:
# --> 181     if zone in all_timezones_set:  # noqa
#     182         fp = open_resource(zone)
#     183         try:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pytz\lazy.py:154, in LazySet.__new__.<locals>.lazy.<locals>._lazy(self, *args, **kw)
#     152 try:
#     153     if len(fill_iter) > 0:
# --> 154         for i in fill_iter.pop():
#     155             set.add(self, i)
#     156         for method_name in cls._props:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pytz\lazy.py:101, in LazyList.__new__.<locals>.lazy.<locals>._lazy(self, *args, **kw)
#      99 try:
#     100     if len(fill_iter) > 0:
# --> 101         list.extend(self, fill_iter.pop())
#     102         for method_name in cls._props:
#     103             delattr(LazyList, method_name)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pytz\__init__.py:1115, in <genexpr>(.0)
#     516     _test()
#     517 _all_timezones_unchecked = \
#     518 ['Africa/Abidjan',
#     519  'Africa/Accra',
#    (...)
#    1112  'WET',
#    1113  'Zulu']
#    1114 all_timezones = LazyList(
# -> 1115         tz for tz in _all_timezones_unchecked if resource_exists(tz))
#    1117 all_timezones_set = LazySet(all_timezones)
#    1118 common_timezones = \
#    1119 ['Africa/Abidjan',
#    1120  'Africa/Accra',
#    (...)
#    1551  'US/Pacific',
#    1552  'UTC']
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pytz\__init__.py:121, in resource_exists(name)
#     114     if os.environ.get('PYTZ_SKIPEXISTSCHECK', ''):
#     115         # In "standard" distributions, we can assume that
#     116         # all the listed timezones are present. As an
#     117         # import-speed optimization, you can set the
#     118         # PYTZ_SKIPEXISTSCHECK flag to skip checking
#     119         # for the presence of the resource file on disk.
#     120         return True
# --> 121     open_resource(name).close()
#     122     return True
#     123 except IOError:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pytz\__init__.py:108, in open_resource(name)
#     106         if resource_stream is not None:
#     107             return resource_stream(__name__, 'zoneinfo/' + name)
# --> 108 return open(filename, 'rb')
#
# KeyboardInterrupt:

# %% [markdown]
# This scheduler can read names and emails from the csv and then send it to them modifying the body text

# %%
import snowflake.connector
import pandas as pd
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import schedule
import time

# Snowflake credentials
username = 'Harshiteggoz'
password = 'Eggoz@123'
account = 'wt08714.ap-south-1.aws'
warehouse = 'COMPUTE_WH'
database = 'EGGOZDB'
schema = 'MAPLEMONK'

# Email credentials 
sender_email = 'abhishektiwari.nssc@gmail.com'
app_password = 'rpax rxpp mpws wzvb' 

# Function to read names and email addresses from a CSV file
def read_email_list(file_path):
    df = pd.read_csv(file_path)
    return df[['Name', 'Email']]

# Function to execute Snowflake SQL Queries
def transform(query):
    conn = snowflake.connector.connect(
        user=username,
        password=password,
        account=account,
        warehouse=warehouse,
        database=database,
        schema=schema
    )
    cur = conn.cursor()
    cur.execute(f"USE {database}.{schema}")

    result_df = pd.read_sql_query(query, conn)
    conn.close()
    return result_df

def fetch_transform_send():
    # Read names and email addresses from the CSV file
    email_list = read_email_list('C:\\Users\\User\\Downloads\\Eggoz\\emails.csv')
   
    # Iterate through each row
    for _, row in email_list.iterrows():
        name = row['Name']
        receiver_email = row['Email']

        # Replace 'your_table' with the actual table name
        query = f"SHOW TABLES IN SCHEMA {schema}"
        result_df = transform(query)

        # Save DataFrame to an Excel file
        excel_file_path = 'transformed_data.csv'
        result_df.to_csv(excel_file_path, index=False)

        # Create Excel attachment
        with open(excel_file_path, 'rb') as file:
            excel_attachment = MIMEText(file.read(), 'base64', 'utf-8')
            excel_attachment.add_header('Content-Disposition', 'attachment', filename='transformed_data.csv')

        # Create email message
        email_message = MIMEMultipart()
        email_message['From'] = sender_email
        email_message['To'] = receiver_email
        email_message['Subject'] = f'Transformed Data for {name}'
        
        # Body text with personalized greeting
        body_text = f'Hi {name},\n\nThis is the transformed data you requested.\n\nBest regards,\nYour Name'
        email_message.attach(MIMEText(body_text, 'plain'))
        
        email_message.attach(excel_attachment)

        # Send email using SMTP
        with smtplib.SMTP('smtp.gmail.com', 587) as server:
            server.starttls()
            server.login(sender_email, app_password)
            server.sendmail(sender_email, receiver_email, email_message.as_string())

# Schedule the message to be sent every hour
schedule.every().minute.do(fetch_transform_send)
# Out:
# Every 1 minute do fetch_transform_send() (last run: [never], next run: 2023-12-08 15:30:41)

# %%
# Run the scheduler loop
while True:
    schedule.run_pending()
    time.sleep(60)  # Sleep for 60 seconds
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\User\Downloads\Eggoz\scheduler_new.ipynb Cell 20 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> # Run the scheduler loop
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#X30sZmlsZQ%3D%3D?line=1'>2</a> while True:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#X30sZmlsZQ%3D%3D?line=2'>3</a>     schedule.run_pending()
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#X30sZmlsZQ%3D%3D?line=3'>4</a>     time.sleep(60)  # Sleep for 60 seconds
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:822, in run_pending()
#     818 def run_pending() -> None:
#     819     """Calls :meth:`run_pending <Scheduler.run_pending>` on the
#     820     :data:`default scheduler instance <default_scheduler>`.
#     821     """
# --> 822     default_scheduler.run_pending()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:100, in Scheduler.run_pending(self)
#      98 runnable_jobs = (job for job in self.jobs if job.should_run)
#      99 for job in sorted(runnable_jobs):
# --> 100     self._run_job(job)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:172, in Scheduler._run_job(self, job)
#     171 def _run_job(self, job: "Job") -> None:
# --> 172     ret = job.run()
#     173     if isinstance(ret, CancelJob) or ret is CancelJob:
#     174         self.cancel_job(job)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:693, in Job.run(self)
#     690     return CancelJob
#     692 logger.debug("Running job %s", self)
# --> 693 ret = self.job_func()
#     694 self.last_run = datetime.datetime.now()
#     695 self._schedule_next_run()
#
# c:\Users\User\Downloads\Eggoz\scheduler_new.ipynb Cell 20 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#X30sZmlsZQ%3D%3D?line=29'>30</a> # Iterate through each row
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#X30sZmlsZQ%3D%3D?line=30'>31</a> for _, row in email_list.iterrows():
# ---> <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#X30sZmlsZQ%3D%3D?line=31'>32</a>     name = row['name']
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#X30sZmlsZQ%3D%3D?line=32'>33</a>     receiver_email = row['email']
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#X30sZmlsZQ%3D%3D?line=34'>35</a>     # Replace 'your_table' with the actual table name
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'name'

# %%
import snowflake.connector
import pandas as pd
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.application import MIMEApplication
import schedule
import time
from apscheduler.schedulers.blocking import BlockingScheduler

from datetime import datetime,timezone


# Snowflake credentials
username = 'Harshiteggoz'
password = 'Eggoz@123'
account = 'wt08714.ap-south-1.aws'
warehouse = 'COMPUTE_WH'
database = 'EGGOZDB'
schema = 'MAPLEMONK'

# Email credentials 
sender_email = 'abhishektiwari.nssc@gmail.com'
app_password = 'rpax rxpp mpws wzvb' 
receiver_email = 'abhitiwari.sirka2001@kgpian.iitkgp.ac.in'
query=None
def transform(query):
    # Execute Snowflake SQL Queries
    # Connecting to Snowflake
    conn = snowflake.connector.connect(
        user=username,
        password=password,
        account=account,
        warehouse=warehouse,
        database=database,
        schema=schema
    )
    cur = conn.cursor()
    cur.execute(f"USE {database}.{schema}")

    result_df = pd.read_sql_query(query, conn)
    return result_df




def fetch_transform_send():

    # Replace 'your_table' with the actual table name
    query = f"SHOW TABLES IN SCHEMA {schema}"
    result_df = transform(query)


    # Convert datetime columns to strings in a specific format
    for col in result_df.select_dtypes(include='datetime64[ns]').columns:
        result_df[col] = result_df[col].dt.strftime('%Y-%m-%d %H:%M:%S')
        
    # Save DataFrame to an Excel file
    excel_file_path = 'transformed_data.xlsx'
    result_df.to_excel(excel_file_path, index=False)

    # Create Excel attachment
    with open(excel_file_path, 'rb') as file:
        excel_attachment = MIMEApplication(file.read(), 'xlsx')
        excel_attachment.add_header('Content-Disposition', 'attachment', filename='transformed_data.xlsx')

    # Create email message
    email_message = MIMEMultipart()
    email_message['From'] = sender_email
    email_message['To'] = receiver_email
    email_message['Subject'] = 'Transformed Data'
    email_message.attach(excel_attachment)

    # Send email using SMTP
    with smtplib.SMTP('smtp.gmail.com', 587) as server:
        server.starttls()
        server.login(sender_email, app_password)
        server.sendmail(sender_email, receiver_email, email_message.as_string())

    conn.close()

# Schedule the message to be sent every hour
schedule.every().minute.do(fetch_transform_send)
# Out:
# Every 1 minute do fetch_transform_send() (last run: [never], next run: 2023-12-10 11:17:51)

# %%
while True:
    schedule.run_pending()
    time.sleep(60)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10800\3732128951.py:41: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result_df = pd.read_sql_query(query, conn)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 while True:
# ----> 2     schedule.run_pending()
#       3     time.sleep(60)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:822, in run_pending()
#     818 def run_pending() -> None:
#     819     """Calls :meth:`run_pending <Scheduler.run_pending>` on the
#     820     :data:`default scheduler instance <default_scheduler>`.
#     821     """
# --> 822     default_scheduler.run_pending()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:100, in Scheduler.run_pending(self)
#      98 runnable_jobs = (job for job in self.jobs if job.should_run)
#      99 for job in sorted(runnable_jobs):
# --> 100     self._run_job(job)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:172, in Scheduler._run_job(self, job)
#     171 def _run_job(self, job: "Job") -> None:
# --> 172     ret = job.run()
#     173     if isinstance(ret, CancelJob) or ret is CancelJob:
#     174         self.cancel_job(job)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:693, in Job.run(self)
#     690     return CancelJob
#     692 logger.debug("Running job %s", self)
# --> 693 ret = self.job_func()
#     694 self.last_run = datetime.datetime.now()
#     695 self._schedule_next_run()
#
# Cell In[5], line 50, in fetch_transform_send()
#      48 # Save DataFrame to an Excel file
#      49 excel_file_path = 'transformed_data.xlsx'
# ---> 50 result_df.to_excel(excel_file_path, index=False)
#      52 # Create Excel attachment
#      53 with open(excel_file_path, 'rb') as file:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:2374, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2361 from pandas.io.formats.excel import ExcelFormatter
#    2363 formatter = ExcelFormatter(
#    2364     df,
#    2365     na_rep=na_rep,
#    (...)
#    2372     inf_rep=inf_rep,
#    2373 )
# -> 2374 formatter.write(
#    2375     excel_writer,
#    2376     sheet_name=sheet_name,
#    2377     startrow=startrow,
#    2378     startcol=startcol,
#    2379     freeze_panes=freeze_panes,
#    2380     engine=engine,
#    2381     storage_options=storage_options,
#    2382 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\formats\excel.py:950, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     947     need_save = True
#     949 try:
# --> 950     writer._write_cells(
#     951         formatted_cells,
#     952         sheet_name,
#     953         startrow=startrow,
#     954         startcol=startcol,
#     955         freeze_panes=freeze_panes,
#     956     )
#     957 finally:
#     958     # make sure to close opened file handles
#     959     if need_save:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\excel\_openpyxl.py:492, in OpenpyxlWriter._write_cells(self, cells, sheet_name, startrow, startcol, freeze_panes)
#     487     freeze_panes = cast(Tuple[int, int], freeze_panes)
#     488     wks.freeze_panes = wks.cell(
#     489         row=freeze_panes[0] + 1, column=freeze_panes[1] + 1
#     490     )
# --> 492 for cell in cells:
#     493     xcell = wks.cell(
#     494         row=startrow + cell.row + 1, column=startcol + cell.col + 1
#     495     )
#     496     xcell.value, fmt = self._value_with_fmt(cell.val)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\formats\excel.py:888, in ExcelFormatter.get_formatted_cells(self)
#     886 def get_formatted_cells(self) -> Iterable[ExcelCell]:
#     887     for cell in itertools.chain(self._format_header(), self._format_body()):
# --> 888         cell.val = self._format_value(cell.val)
#     889         yield cell
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\formats\excel.py:602, in ExcelFormatter._format_value(self, val)
#     600         val = float(self.float_format % val)
#     601 if getattr(val, "tzinfo", None) is not None:
# --> 602     raise ValueError(
#     603         "Excel does not support datetimes with "
#     604         "timezones. Please ensure that datetimes "
#     605         "are timezone unaware before writing to Excel."
#     606     )
#     607 return val
#
# ValueError: Excel does not support datetimes with timezones. Please ensure that datetimes are timezone unaware before writing to Excel.

# %%
import snowflake.connector
import pandas as pd
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import schedule
import time

# Snowflake credentials
username = 'Harshiteggoz'
password = 'Eggoz@123'
account = 'wt08714.ap-south-1.aws'
warehouse = 'COMPUTE_WH'
database = 'EGGOZDB'
schema = 'MAPLEMONK'

# Email credentials 
sender_email = 'abhishektiwari.nssc@gmail.com'
app_password = 'rpax rxpp mpws wzvb' 
receiver_email = 'puneet.gulati@eggoz.in'

def fetch_transform_send(query):
    # Connecting to Snowflake
    conn = snowflake.connector.connect(
        user=username,
        password=password,
        account=account,
        warehouse=warehouse,
        database=database,
        schema=schema
    )

    # Execute Snowflake SQL Queries
    cur = conn.cursor()
    cur.execute(f"USE {database}.{schema}")

    # Replace 'your_table' with the actual table name
    result_df = pd.read_sql_query(query, conn)

    # Save DataFrame to an Excel file
    excel_file_path = 'transformed_data.csv'
    result_df.to_csv(excel_file_path, index=False)

    # Create Excel attachment
    with open(excel_file_path, 'rb') as file:
        excel_attachment = MIMEText(file.read(), 'base64', 'utf-8')
        excel_attachment.add_header('Content-Disposition', 'attachment', filename='transformed_data.csv')

    # Create email message
    email_message = MIMEMultipart()
    email_message['From'] = sender_email
    email_message['To'] = receiver_email
    email_message['Subject'] = 'Transformed Data'
    email_message.attach(excel_attachment)

    # Send email using SMTP
    with smtplib.SMTP('smtp.gmail.com', 587) as server:
        server.starttls()
        server.login(sender_email, app_password)
        server.sendmail(sender_email, receiver_email, email_message.as_string())

    conn.close()

# Replace 'your_table' with the actual table name
query = f"SHOW TABLES IN SCHEMA {schema}"

# Schedule the message to be sent every hour
schedule.every(1).hour.do(fetch_transform_send, query)
# Out:
# Every 1 hour do fetch_transform_send('SHOW TABLES IN SCHEMA MAPLEMONK') (last run: [never], next run: 2023-12-07 19:23:47)

# %%
import snowflake.connector
import pandas as pd
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import schedule
import time

# Snowflake credentials
username = 'Harshiteggoz'
password = 'Eggoz@123'
account = 'wt08714.ap-south-1.aws'
warehouse = 'COMPUTE_WH'
database = 'EGGOZDB'
schema = 'MAPLEMONK'

# Email credentials 
sender_email = 'abhishektiwari.nssc@gmail.com'
app_password = 'rpax rxpp mpws wzvb' 
receiver_email = 'abhitiwari.sirka2001@kgpian.iitkgp.ac.in'

def fetch_transform_send():
    # Connecting to Snowflake
    
    
    conn = snowflake.connector.connect(
        user=username,
        password=password,
        account=account,
        warehouse=warehouse,
        database=database,
        schema=schema
    )

    # Execute Snowflake SQL Queries
    cur = conn.cursor()
    query=None
    cur.execute(query)
    cur.execute(f"USE {database}.{schema}")

    # Replace 'your_table' with the actual table name
    query = f"SHOW TABLES IN SCHEMA {schema}"
    result_df = pd.read_sql_query(query, conn)

    # Save DataFrame to an Excel file
    excel_file_path = 'transformed_data.csv'
    result_df.to_csv(excel_file_path, index=False)

    # Create Excel attachment
    with open(excel_file_path, 'rb') as file:
        excel_attachment = MIMEText(file.read(), 'base64', 'utf-8')
        excel_attachment.add_header('Content-Disposition', 'attachment', filename='transformed_data.csv')

    # Create email message
    email_message = MIMEMultipart()
    email_message['From'] = sender_email
    email_message['To'] = receiver_email
    email_message['Subject'] = 'Transformed Data'
    email_message.attach(excel_attachment)

    # Send email using SMTP
    with smtplib.SMTP('smtp.gmail.com', 587) as server:
        server.starttls()
        server.login(sender_email, app_password)
        server.sendmail(sender_email, receiver_email, email_message.as_string())

    conn.close()

# Schedule the message to be sent every hour
schedule.every(1).hour.do(fetch_transform_send)

# Run the scheduler loop
while True:
    query=None
    schedule.run_pending()
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# c:\Users\User\Downloads\Eggoz\scheduler_new.ipynb Cell 15 line 7
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#X20sZmlsZQ%3D%3D?line=72'>73</a> while True:
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#X20sZmlsZQ%3D%3D?line=73'>74</a>     query=None
# ---> <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#X20sZmlsZQ%3D%3D?line=74'>75</a>     schedule.run_pending()
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#X20sZmlsZQ%3D%3D?line=75'>76</a>     time.sleep(1)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:822, in run_pending()
#     818 def run_pending() -> None:
#     819     """Calls :meth:`run_pending <Scheduler.run_pending>` on the
#     820     :data:`default scheduler instance <default_scheduler>`.
#     821     """
# --> 822     default_scheduler.run_pending()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:100, in Scheduler.run_pending(self)
#      98 runnable_jobs = (job for job in self.jobs if job.should_run)
#      99 for job in sorted(runnable_jobs):
# --> 100     self._run_job(job)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:172, in Scheduler._run_job(self, job)
#     171 def _run_job(self, job: "Job") -> None:
# --> 172     ret = job.run()
#     173     if isinstance(ret, CancelJob) or ret is CancelJob:
#     174         self.cancel_job(job)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:693, in Job.run(self)
#     690     return CancelJob
#     692 logger.debug("Running job %s", self)
# --> 693 ret = self.job_func()
#     694 self.last_run = datetime.datetime.now()
#     695 self._schedule_next_run()
#
# c:\Users\User\Downloads\Eggoz\scheduler_new.ipynb Cell 15 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#X20sZmlsZQ%3D%3D?line=35'>36</a> sql_query = "USE EGGOZDB"
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#X20sZmlsZQ%3D%3D?line=36'>37</a> cur = conn.cursor()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#X20sZmlsZQ%3D%3D?line=37'>38</a> cur.execute(query)
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#X20sZmlsZQ%3D%3D?line=39'>40</a> query = f"SHOW TABLES IN SCHEMA {schema}"
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/Eggoz/scheduler_new.ipynb#X20sZmlsZQ%3D%3D?line=40'>41</a> cur.execute(query)
#
# UnboundLocalError: local variable 'query' referenced before assignment

# %%
# !pip install xlsxwriter
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting xlsxwriter
#   Downloading XlsxWriter-3.1.9-py3-none-any.whl (154 kB)
#      ---------------------------------------- 0.0/154.8 kB ? eta -:--:--
#      --------------------------- ---------- 112.6/154.8 kB 2.2 MB/s eta 0:00:01
#      -------------------------------------- 154.8/154.8 kB 1.3 MB/s eta 0:00:00
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.1.9
# [notice] A new release of pip is available: 23.0.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import snowflake.connector
import pandas as pd
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import schedule
import time
from datetime import datetime, timezone


# Snowflake credentials
username = 'Harshiteggoz'
password = 'Eggoz@123'
account = 'wt08714.ap-south-1.aws'
warehouse = 'COMPUTE_WH'
database = 'EGGOZDB'
schema = 'MAPLEMONK'

# Connecting to Snowflake
conn = snowflake.connector.connect(
    user=username,
    password=password,
    account=account,
    warehouse=warehouse,
    database=database,
    schema=schema
)
# Email credentials 
sender_email = 'abhishektiwari.nssc@gmail.com'
app_password = 'rpax rxpp mpws wzvb' 
receiver_email = 'abhitiwari.sirka2001@kgpian.iitkgp.ac.in'
query=None
def transform(query):
    # Execute Snowflake SQL Queries
    # Connecting to Snowflake
    conn = snowflake.connector.connect(
        user=username,
        password=password,
        account=account,
        warehouse=warehouse,
        database=database,
        schema=schema
    )
    cur = conn.cursor()
    cur.execute(f"USE {database}.{schema}")


    result_df = pd.read_sql_query(query, conn)

    # Convert 'date' column to date without timezone
    result_df['created_on'] = pd.to_datetime(result_df['created_on']).dt.date
    return result_df


def fetch_transform_send():

    # Replace 'your_table' with the actual table name
    query = f"SHOW TABLES IN SCHEMA {schema}"
    result_df = transform(query)

    # Save DataFrame to an Excel file
    excel_file_path = 'transformed_data.xlsx'
    with pd.ExcelWriter(excel_file_path, engine='xlsxwriter') as writer:
    # Write each DataFrame to a different sheet
         result_df.to_excel(writer, sheet_name='Sheet1', index=False)


    # Create Excel attachment
    with open(excel_file_path, 'rb') as file:
        excel_attachment = MIMEText(file.read(), 'base64', 'utf-8')
        excel_attachment.add_header('Content-Disposition', 'attachment', filename='transformed_data.xlsx')

    # Create email message
    email_message = MIMEMultipart()
    email_message['From'] = sender_email
    email_message['To'] = receiver_email
    email_message['Subject'] = 'Transformed Data'
    email_message.attach(excel_attachment)

    # Send email using SMTP
    with smtplib.SMTP('smtp.gmail.com', 587) as server:
        server.starttls()
        server.login(sender_email, app_password)
        server.sendmail(sender_email, receiver_email, email_message.as_string())

    conn.close()

# Schedule the message to be sent every hour
schedule.every().minute.do(fetch_transform_send)
# Out:
# Every 1 minute do fetch_transform_send() (last run: [never], next run: 2023-12-10 11:46:08)

# %%
while True:
    schedule.run_pending()
    time.sleep(60)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_20752\2976778468.py:48: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result_df = pd.read_sql_query(query, conn)
# C:\Users\User\AppData\Local\Temp\ipykernel_20752\2976778468.py:48: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result_df = pd.read_sql_query(query, conn)
# C:\Users\User\AppData\Local\Temp\ipykernel_20752\2976778468.py:48: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result_df = pd.read_sql_query(query, conn)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 while True:
# ----> 2     schedule.run_pending()
#       3     time.sleep(60)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:822, in run_pending()
#     818 def run_pending() -> None:
#     819     """Calls :meth:`run_pending <Scheduler.run_pending>` on the
#     820     :data:`default scheduler instance <default_scheduler>`.
#     821     """
# --> 822     default_scheduler.run_pending()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:100, in Scheduler.run_pending(self)
#      98 runnable_jobs = (job for job in self.jobs if job.should_run)
#      99 for job in sorted(runnable_jobs):
# --> 100     self._run_job(job)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:172, in Scheduler._run_job(self, job)
#     171 def _run_job(self, job: "Job") -> None:
# --> 172     ret = job.run()
#     173     if isinstance(ret, CancelJob) or ret is CancelJob:
#     174         self.cancel_job(job)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:693, in Job.run(self)
#     690     return CancelJob
#     692 logger.debug("Running job %s", self)
# --> 693 ret = self.job_func()
#     694 self.last_run = datetime.datetime.now()
#     695 self._schedule_next_run()
#
# Cell In[6], line 83, in fetch_transform_send()
#      81 with smtplib.SMTP('smtp.gmail.com', 587) as server:
#      82     server.starttls()
# ---> 83     server.login(sender_email, app_password)
#      84     server.sendmail(sender_email, receiver_email, email_message.as_string())
#      86 conn.close()
#
# File c:\Program Files\Python310\lib\smtplib.py:714, in SMTP.login(self, user, password, initial_response_ok)
#     686 def login(self, user, password, *, initial_response_ok=True):
#     687     """Log in on an SMTP server that requires authentication.
#     688
#     689     The arguments are:
#    (...)
#     711                               found.
#     712     """
# --> 714     self.ehlo_or_helo_if_needed()
#     715     if not self.has_extn("auth"):
#     716         raise SMTPNotSupportedError(
#     717             "SMTP AUTH extension not supported by server.")
#
# File c:\Program Files\Python310\lib\smtplib.py:611, in SMTP.ehlo_or_helo_if_needed(self)
#     600 """Call self.ehlo() and/or self.helo() if needed.
#     601
#     602 If there has been no previous EHLO or HELO command this session, this
#    (...)
#     608                           the helo greeting.
#     609 """
#     610 if self.helo_resp is None and self.ehlo_resp is None:
# --> 611     if not (200 <= self.ehlo()[0] <= 299):
#     612         (code, resp) = self.helo()
#     613         if not (200 <= code <= 299):
#
# File c:\Program Files\Python310\lib\smtplib.py:452, in SMTP.ehlo(self, name)
#     450 self.esmtp_features = {}
#     451 self.putcmd(self.ehlo_msg, name or self.local_hostname)
# --> 452 (code, msg) = self.getreply()
#     453 # According to RFC1869 some (badly written)
#     454 # MTA's will disconnect on an ehlo. Toss an exception if
#     455 # that happens -ddm
#     456 if code == -1 and len(msg) == 0:
#
# File c:\Program Files\Python310\lib\smtplib.py:398, in SMTP.getreply(self)
#     396 while 1:
#     397     try:
# --> 398         line = self.file.readline(_MAXLINE + 1)
#     399     except OSError as e:
#     400         self.close()
#
# File c:\Program Files\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File c:\Program Files\Python310\lib\ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1269     if flags != 0:
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#    1275     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Program Files\Python310\lib\ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1127 try:
#    1128     if buffer is not None:
# -> 1129         return self._sslobj.read(len, buffer)
#    1130     else:
#    1131         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import snowflake.connector
import pandas as pd
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import schedule
import time
from datetime import datetime, timezone

# Snowflake credentials
username = 'Harshiteggoz'
password = 'Eggoz@123'
account = 'wt08714.ap-south-1.aws'
warehouse = 'COMPUTE_WH'
database = 'EGGOZDB'
schema = 'MAPLEMONK'

# Connecting to Snowflake
conn = snowflake.connector.connect(
    user=username,
    password=password,
    account=account,
    warehouse=warehouse,
    database=database,
    schema=schema
)

# Email credentials
sender_email = 'abhishektiwari.nssc@gmail.com'
app_password = 'rpax rxpp mpws wzvb'
excel_file_path = 'transformed_data.xlsx'  # Use the same file for all recipients

# Read emails and names from CSV
emails_df = pd.read_csv('emails.csv')

def transform(query):
    # Execute Snowflake SQL Queries
    # Connecting to Snowflake
    conn = snowflake.connector.connect(
        user=username,
        password=password,
        account=account,
        warehouse=warehouse,
        database=database,
        schema=schema
    )
    cur = conn.cursor()
    cur.execute(f"USE {database}.{schema}")

    result_df = pd.read_sql_query(query, conn)

    # Convert 'date' column to date without timezone
    result_df['created_on'] = pd.to_datetime(result_df['created_on']).dt.date
    return result_df

def send_email(name, email):
    # Create Excel attachment
    with open(excel_file_path, 'rb') as file:
        excel_attachment = MIMEText(file.read(), 'base64', 'utf-8')
        excel_attachment.add_header('Content-Disposition', 'attachment', filename='transformed_data.xlsx')

    # Create email message
    email_message = MIMEMultipart()
    email_message['From'] = sender_email
    email_message['To'] = email
    email_message['Subject'] = 'Transformed Data'
    email_message.attach(excel_attachment)

    # Customize email body
    email_body = f"Hi {name},\nPlease find attached the transformed dataset\nThanks"
    email_message.attach(MIMEText(email_body, 'plain'))

    # Send email using SMTP
    with smtplib.SMTP('smtp.gmail.com', 587) as server:
        server.starttls()
        server.login(sender_email, app_password)
        server.sendmail(sender_email, email, email_message.as_string())

def fetch_transform_send():
    # Replace 'your_table' with the actual table name
    query = f"SHOW TABLES IN SCHEMA {schema}"
    result_df = transform(query)

    # Save DataFrame to an Excel file
    with pd.ExcelWriter(excel_file_path, engine='xlsxwriter') as writer:
        # Write each DataFrame to a different sheet
        result_df.to_excel(writer, sheet_name='Sheet1', index=False)
    print(emails_df.columns)
    # Send customized emails to each recipient
    for index, row in emails_df.iterrows():
        print(index)
        send_email(row['name'], row['email'])

    conn.close()

# Schedule the message to be sent every hour
schedule.every().minute.do(fetch_transform_send)
# Out:
# Every 1 minute do fetch_transform_send() (last run: [never], next run: 2023-12-10 12:02:20)

# %%
while True:
    schedule.run_pending()
    time.sleep(1)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_20752\3039378204.py:50: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result_df = pd.read_sql_query(query, conn)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 2
#       1 while True:
# ----> 2     schedule.run_pending()
#       3     time.sleep(1)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:822, in run_pending()
#     818 def run_pending() -> None:
#     819     """Calls :meth:`run_pending <Scheduler.run_pending>` on the
#     820     :data:`default scheduler instance <default_scheduler>`.
#     821     """
# --> 822     default_scheduler.run_pending()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:100, in Scheduler.run_pending(self)
#      98 runnable_jobs = (job for job in self.jobs if job.should_run)
#      99 for job in sorted(runnable_jobs):
# --> 100     self._run_job(job)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:172, in Scheduler._run_job(self, job)
#     171 def _run_job(self, job: "Job") -> None:
# --> 172     ret = job.run()
#     173     if isinstance(ret, CancelJob) or ret is CancelJob:
#     174         self.cancel_job(job)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:693, in Job.run(self)
#     690     return CancelJob
#     692 logger.debug("Running job %s", self)
# --> 693 ret = self.job_func()
#     694 self.last_run = datetime.datetime.now()
#     695 self._schedule_next_run()
#
# Cell In[10], line 91, in fetch_transform_send()
#      89 # Send customized emails to each recipient
#      90 for index, row in emails_df.iterrows():
# ---> 91     send_email(row['Name'], row['Email'])
#      93 conn.close()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Name'

# %%
import snowflake.connector
import pandas as pd
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import schedule
import time
from datetime import datetime, timezone

# Snowflake credentials
username = 'Harshiteggoz'
password = 'Eggoz@123'
account = 'wt08714.ap-south-1.aws'
warehouse = 'COMPUTE_WH'
database = 'EGGOZDB'
schema = 'MAPLEMONK'


# Email credentials
sender_email = 'abhishektiwari.nssc@gmail.com'
app_password = 'rpax rxpp mpws wzvb'
excel_file_path = 'transformed_data.xlsx'  # Use the same file for all recipients

# Read emails and names from CSV
emails_df = pd.read_csv('emails.csv')

def transform(query):
    # Execute Snowflake SQL Queries
    # Connecting to Snowflake
    conn = snowflake.connector.connect(
        user=username,
        password=password,
        account=account,
        warehouse=warehouse,
        database=database,
        schema=schema
    )
    cur = conn.cursor()
    cur.execute(f"USE {database}.{schema}")

    result_df = pd.read_sql_query(query, conn)

    # Convert 'date' column to date without timezone
    result_df['created_on'] = pd.to_datetime(result_df['created_on']).dt.date
    return result_df

def send_email(name, email):
    # Create Excel attachment
    with open(excel_file_path, 'rb') as file:
        excel_attachment = MIMEText(file.read(), 'base64', 'utf-8')
        excel_attachment.add_header('Content-Disposition', 'attachment', filename='transformed_data.xlsx')

    # Create email message
    email_message = MIMEMultipart()
    email_message['From'] = sender_email
    email_message['To'] = email
    email_message['Subject'] = 'Transformed Data'
    email_message.attach(excel_attachment)

    # Customize email body
    email_body = f"Hi {name},\nPlease find attached the transformed dataset\nThanks"
    email_message.attach(MIMEText(email_body, 'plain'))

    # Send email using SMTP
    with smtplib.SMTP('smtp.gmail.com', 587) as server:
        server.starttls()
        server.login(sender_email, app_password)
        server.sendmail(sender_email, email, email_message.as_string())

def fetch_transform_send():
    # Replace 'your_table' with the actual table name
    query = f"SHOW TABLES IN SCHEMA {schema}"
    result_df = transform(query)

    # Save DataFrame to an Excel file
    with pd.ExcelWriter(excel_file_path, engine='xlsxwriter') as writer:
        # Write each DataFrame to a different sheet
        result_df.to_excel(writer, sheet_name='Sheet1', index=False)
    
    # Send customized emails to each recipient
    for index, row in emails_df.iterrows():
        send_email(row['name'], row['email'])
        if index == len(emails_df) - 1:
            break

    conn.close()

# Schedule the message to be sent every hour
schedule.every().minute.do(fetch_transform_send)
# Out:
# Index(['name', 'email'], dtype='object')
# Every 1 minute do fetch_transform_send() (last run: [never], next run: 2023-12-10 12:07:48)

# %%
for index, row in emails_df.iterrows():
    print(row['name'])
    print(row['email'])
    print()
# Out:
# Abhishek
# abhitiwari.sirka2001@kgpian.iitkgp.ac.in
#
# Puneet
# puneet.gulati@eggoz.in
#
# Abhi
# abhishek.tiwari@eggoz.in

# %%
while True:
    schedule.run_pending()
    time.sleep(60)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_20752\2648429286.py:50: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result_df = pd.read_sql_query(query, conn)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 2
#       1 while True:
# ----> 2     schedule.run_pending()
#       3     time.sleep(60)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:822, in run_pending()
#     818 def run_pending() -> None:
#     819     """Calls :meth:`run_pending <Scheduler.run_pending>` on the
#     820     :data:`default scheduler instance <default_scheduler>`.
#     821     """
# --> 822     default_scheduler.run_pending()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:100, in Scheduler.run_pending(self)
#      98 runnable_jobs = (job for job in self.jobs if job.should_run)
#      99 for job in sorted(runnable_jobs):
# --> 100     self._run_job(job)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:172, in Scheduler._run_job(self, job)
#     171 def _run_job(self, job: "Job") -> None:
# --> 172     ret = job.run()
#     173     if isinstance(ret, CancelJob) or ret is CancelJob:
#     174         self.cancel_job(job)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\schedule\__init__.py:693, in Job.run(self)
#     690     return CancelJob
#     692 logger.debug("Running job %s", self)
# --> 693 ret = self.job_func()
#     694 self.last_run = datetime.datetime.now()
#     695 self._schedule_next_run()
#
# Cell In[10], line 91, in fetch_transform_send()
#      89 # Send customized emails to each recipient
#      90 for index, row in emails_df.iterrows():
# ---> 91     send_email(row['Name'], row['Email'])
#      93 conn.close()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Name'
