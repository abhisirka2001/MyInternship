# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import statsmodels.api as sm
import tensorflow as tf
import xgboost as xgb
import os
import warnings
from tensorflow.keras.layers import Dense, LSTM, Conv1D, MaxPooling1D, TimeDistributed, Flatten, Dropout, RepeatVector
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller, kpss, ccf
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from math import sqrt
from sklearn.metrics import mean_squared_error
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/power-demand-data/demand_Data.csv
# /kaggle/input/weather-data/finWeatherData.csv

# %%
df_weather =  pd.read_csv("/kaggle/input/weather-data/finWeatherData.csv",index_col = 0,parse_dates=True)

# %%
df_weather.head()
# Out:
#          Date       Tmax       Tmin  Rain
# 0  2019-01-01  28.696802  14.070121   0.0
# 1  2019-01-02  29.149151  14.778795   0.0
# 2  2019-01-03  29.741541  15.863366   0.0
# 3  2019-01-04  29.451434  16.492335   0.0
# 4  2019-01-05  28.863384  16.951641   0.0

# %%
df_demand = pd.read_csv("/kaggle/input/power-demand-data/demand_Data.csv",parse_dates =True)

# %%
df_demand.head()
# Out:
#         Date  Energy Required (MU)
# 0  02-May-12               255.639
# 1  03-May-12               258.470
# 2  04-May-12               261.393
# 3  05-May-12               252.866
# 4  06-May-12               250.566

# %%
# Convert the date column to datetime format
df_demand['Date'] = pd.to_datetime(df_demand['Date'],errors="coerce", format="%d-%b-%y")

# Convert the date column to the desired format
df_demand['Date'] = df_demand['Date'].dt.strftime("%d/%m/%Y")

# %%
import pandas as pd

# Convert the "Date" column in df_energy to datetime format
df_demand['Date'] = pd.to_datetime(df_demand['Date'])

# Filter df_energy to include dates starting from 01/01/2019
df_demand = df_demand[df_demand['Date'] >= '2019-01-01']

# Convert the "Date" column in df_weather to datetime format
df_weather['Date'] = pd.to_datetime(df_weather['Date'])

# Filter df_weather to include dates starting from 01/01/2019
df_demand = df_demand[df_demand['Date'] >= '2019-01-01']

# Merge the two DataFrames based on the "Date" column
merged_df = pd.merge(df_demand, df_weather, on='Date', how='inner')
# Out:
# /tmp/ipykernel_32/3321147370.py:4: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df_demand['Date'] = pd.to_datetime(df_demand['Date'])

# %%
merged_df
# Out:
#            Date  Energy Required (MU)       Tmax       Tmin      Rain
# 0    2019-01-01               152.233  28.696802  14.070121  0.000000
# 1    2019-02-01               155.343  29.408003  18.148469  0.000000
# 2    2019-03-01               157.659  33.184526  23.714411  1.550007
# 3    2019-04-01               159.317  37.308186  25.592237  0.025442
# 4    2019-05-01               159.691  36.672354  27.560249  1.480898
# ...         ...                   ...        ...        ...       ...
# 1553 2023-03-05               188.591  35.240079  19.384070  0.000000
# 1554 2023-04-05               193.000  35.972310  25.309858  0.392332
# 1555 2023-05-05               193.201  33.934335  25.928193  2.541572
# 1556 2023-05-13               224.030  38.145824  27.398606  0.000000
# 1557 2023-05-14               226.349  39.622750  27.568079  0.000000
#
# [1558 rows x 5 columns]

# %%
merged_df = merged_df.set_index("Date")

# %%
merged_df.isna().sum()
# Out:
# Energy Required (MU)    0
# Tmax                    0
# Tmin                    0
# Rain                    0
# dtype: int64

# %%
sns.boxplot(x=merged_df['Rain'])
plt.show()

# %%
sns.boxplot(x=merged_df['Tmax'])
plt.show()

# %%
sns.boxplot(x=merged_df['Tmin'])
plt.show()

# %%
sns.boxplot(x=merged_df['Energy Required (MU)'])
plt.show()

# %%
# Convert index to a DatetimeIndex with a frequency
merged_df.index = pd.date_range(start=merged_df.index[0], periods=len(merged_df), freq='D')

# %%
plt.figure(figsize=(30,10))
plt.plot(merged_df["Energy Required (MU)"])
plt.xticks(rotation=90)
# Out:
# (array([17897., 18078., 18262., 18444., 18628., 18809., 18993., 19174.,
#         19358.]),
#  [Text(17897.0, 0, '2019-01'),
#   Text(18078.0, 0, '2019-07'),
#   Text(18262.0, 0, '2020-01'),
#   Text(18444.0, 0, '2020-07'),
#   Text(18628.0, 0, '2021-01'),
#   Text(18809.0, 0, '2021-07'),
#   Text(18993.0, 0, '2022-01'),
#   Text(19174.0, 0, '2022-07'),
#   Text(19358.0, 0, '2023-01')])

# %%
plt.figure(figsize=(30,10))
plt.plot(merged_df["Rain"])
plt.xticks(rotation=90)
# Out:
# (array([17897., 18078., 18262., 18444., 18628., 18809., 18993., 19174.,
#         19358.]),
#  [Text(17897.0, 0, '2019-01'),
#   Text(18078.0, 0, '2019-07'),
#   Text(18262.0, 0, '2020-01'),
#   Text(18444.0, 0, '2020-07'),
#   Text(18628.0, 0, '2021-01'),
#   Text(18809.0, 0, '2021-07'),
#   Text(18993.0, 0, '2022-01'),
#   Text(19174.0, 0, '2022-07'),
#   Text(19358.0, 0, '2023-01')])

# %%
plt.figure(figsize=(30,10))
plt.plot((merged_df["Tmax"]+merged_df["Tmin"])/2)
plt.xticks(rotation=90)
# Out:
# (array([17897., 18078., 18262., 18444., 18628., 18809., 18993., 19174.,
#         19358.]),
#  [Text(17897.0, 0, '2019-01'),
#   Text(18078.0, 0, '2019-07'),
#   Text(18262.0, 0, '2020-01'),
#   Text(18444.0, 0, '2020-07'),
#   Text(18628.0, 0, '2021-01'),
#   Text(18809.0, 0, '2021-07'),
#   Text(18993.0, 0, '2022-01'),
#   Text(19174.0, 0, '2022-07'),
#   Text(19358.0, 0, '2023-01')])

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt

# Perform seasonal decomposition
res = sm.tsa.seasonal_decompose(merged_df['Energy Required (MU)'], model='additive')

# Plot the decomposed components
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(20, 12))
res.observed.plot(ax=ax1, title='Observed')
res.trend.plot(ax=ax2, title='Trend')
res.resid.plot(ax=ax3, title='Residual')
res.seasonal.plot(ax=ax4, title='Seasonal')
plt.tight_layout()
plt.show()

# %%
y = merged_df['Energy Required (MU)']
adf_test = adfuller(y, regression='c')
print('ADF Statistic: {:.6f}\np-value: {:.6f}\n#Lags used: {}'
      .format(adf_test[0], adf_test[1], adf_test[2]))
for key, value in adf_test[4].items():
    print('Critical Value ({}): {:.6f}'.format(key, value))
# Out:
# ADF Statistic: -3.951004
# p-value: 0.001690
# #Lags used: 15
# Critical Value (1%): -3.434598
# Critical Value (5%): -2.863416
# Critical Value (10%): -2.567769

# %% [markdown]
# The **ADF statistic** (-3.951004) is less than the critical value at 5% (-2.863416) and thus, we can say that **we reject the null hypothesis $H_{0}$ with a significance level 1%**, meaning that there is not a root-unit in the time series and thus, that it is **either stationary or could be made stationary** with 1st order differencing (difference-stationary).

# %%
from statsmodels.tsa.stattools import kpss

kpss_test = kpss(y, regression='c')
print('KPSS Statistic: {:.6f}\np-value: {:.6f}\n#Lags used: {}'
      .format(kpss_test[0], kpss_test[1], kpss_test[2]))
for key, value in kpss_test[3].items():
    print(f'Critical value ({key}): {value}')
# Out:
# KPSS Statistic: 1.972154
# p-value: 0.010000
# #Lags used: 25
# Critical value (10%): 0.347
# Critical value (5%): 0.463
# Critical value (2.5%): 0.574
# Critical value (1%): 0.739
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/stattools.py:2018: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(

# %% [markdown]
# The **KPSS statistic (1.972154)** is higher than the critical value at 5% (0.739) and thus, we can say that **we cannot reject the null hypothesis $H_{0}$ with a significance level 5%**, meaning that the **time series is stationary **or stationary around a constant.

# %%
# Plot autocorrelation and partial autocorrelation plots

fig, (ax1, ax2) = plt.subplots(nrows=2, figsize=(10, 6))
plot_acf(merged_df['Energy Required (MU)'], lags=50, ax=ax1)
plot_pacf(merged_df['Energy Required (MU)'], lags=50, ax=ax2)
plt.tight_layout()
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
cross_corr = ccf(merged_df['Energy Required (MU)'], merged_df['Energy Required (MU)'])
plt.plot(cross_corr[0:100])
plt.show()

# %%
correlations = merged_df.corr(method='pearson')
print(correlations['Energy Required (MU)'].sort_values(ascending=False).to_string())
# Out:
# Energy Required (MU)    1.000000
# Tmax                    0.336400
# Tmin                    0.081247
# Rain                   -0.256393

# %%
correlations = merged_df.corr(method='pearson')
fig = plt.figure(figsize=(10, 10))
sns.heatmap(correlations, annot=True, fmt='.2f')
plt.title('Pearson Correlation Matrix')
plt.show()

# %%
highly_correlated = abs(correlations[correlations > 0.75])
print(highly_correlated[highly_correlated < 1.0].stack().to_string())
# Out:
# Series([], )

# %%
def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
    data = []
    labels = []

    start_index = start_index + history_size
    if end_index is None:
        end_index = len(dataset) - target_size
        
    for i in range(start_index, end_index):
        indices = range(i-history_size, i, step)
        data.append(dataset[indices])
        
        if single_step:
            labels.append(target[i + target_size])
        else:
            labels.append(target[i : i + target_size])

    return np.array(data), np.array(labels)

# %%
X = merged_df.values
y = merged_df['Energy Required (MU)'].values

# %%
X.shape
# Out:
# (1558, 4)

# %%
train_end_idx = 1200
cv_end_idx = 1396
test_end_idx = 1557

# %%
X
# Out:
# array([[152.233     ,  28.69680159,  14.07012138,   0.        ],
#        [155.343     ,  29.40800289,  18.14846943,   0.        ],
#        [157.659     ,  33.18452609,  23.71441105,   1.55000675],
#        ...,
#        [193.201     ,  33.9343353 ,  25.92819331,   2.54157166],
#        [224.03      ,  38.14582355,  27.39860641,   0.        ],
#        [226.349     ,  39.62275041,  27.56807882,   0.        ]])

# %%
y = y.reshape(-1, 1)
y
# Out:
# array([[152.233],
#        [155.343],
#        [157.659],
#        ...,
#        [193.201],
#        [224.03 ],
#        [226.349]])

# %%
scaler_X = MinMaxScaler(feature_range=(0, 1))
scaler_y = MinMaxScaler(feature_range=(0, 1))

# %%
scaler_X.fit(X[:train_end_idx])
scaler_y.fit(y[:train_end_idx])
# Out:
# MinMaxScaler()

# %%
X_norm = scaler_X.transform(X)
y_norm = scaler_y.transform(y)

# %%
def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
    data = []
    labels = []
    if start_index==0:
        start_index = start_index + history_size
    else:
        start_index=start_index
    if end_index is None:
        end_index = len(dataset) - target_size
        
    for i in range(start_index, end_index):
        indices = range(i-history_size, i, step)
        data.append(dataset[indices])
        
        if single_step:
            labels.append(target[i + target_size])
        else:
            labels.append(target[i : i + target_size])

    return np.array(data), np.array(labels)

# %%
dataset_norm = np.concatenate((X_norm, y_norm), axis=1)
n_features = 4
past_history = 28
future_target = 1

# %%
dataset_norm.shape
# Out:
# (1558, 5)

# %%
X_train, y_train = multivariate_data(dataset_norm[:,0:-1], dataset_norm[:, -1],
                                     0, train_end_idx, past_history, 
                                     future_target, step=1, single_step=True)

# %%
X_train.shape
# Out:
# (1172, 28, 4)

# %%
X_val, y_val = multivariate_data(dataset_norm[:,0:-1], dataset_norm[:, 0],
                                 train_end_idx, cv_end_idx, past_history, 
                                 future_target, step=1, single_step=True)

# %%
X_val.shape
# Out:
# (196, 28, 4)

# %%
y_val.shape
# Out:
# (196,)

# %%
X_test, y_test = multivariate_data(dataset_norm[:,0:-1], dataset_norm[:, 0],
                                   cv_end_idx, test_end_idx, past_history, 
                                   future_target, step=1, single_step=True)

# %%
X_test.shape
# Out:
# (161, 28, 4)

# %%
batch_size = 32
buffer_size = 1000

# %%
X_train.shape
# Out:
# (1172, 28, 4)

# %%
train = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train = train.cache().shuffle(buffer_size).batch(batch_size).prefetch(1)

validation = tf.data.Dataset.from_tensor_slices((X_val, y_val))
validation = validation.batch(batch_size).prefetch(1)

# %%
# Define some common parameters

input_shape = X_train.shape[-2:]
loss = tf.keras.losses.MeanSquaredError()
metric = [tf.keras.metrics.RootMeanSquaredError()]
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
              lambda epoch: 1e-4 * 10**(epoch / 10))
early_stopping = tf.keras.callbacks.EarlyStopping(patience=10)

# %%
y_test
# Out:
# array([0.62140188, 0.51850698, 0.51421218, 0.5332847 , 0.55178349,
#        0.58242082, 0.5607747 , 0.59055964, 0.6202708 , 0.6202708 ,
#        0.58420759, 0.56661858, 0.4720756 , 0.49577897, 0.52704741,
#        0.53399777, 0.52703101, 0.55593895, 0.55384073, 0.55268507,
#        0.5264081 , 0.48773031, 0.50672087, 0.47523933, 0.50827815,
#        0.53465347, 0.55353747, 0.53074389, 0.55102124, 0.55643073,
#        0.58522392, 0.61206642, 0.60770605, 0.63105698, 0.60860763,
#        0.63129467, 0.59599371, 0.54513638, 0.54486591, 0.4379303 ,
#        0.25857321, 0.2519261 , 0.32135598, 0.35198512, 0.40044095,
#        0.41098944, 0.46410071, 0.49036129, 0.4435037 , 0.4686332 ,
#        0.50582749, 0.53085863, 0.54349715, 0.54026785, 0.55293096,
#        0.48501738, 0.51260573, 0.57651138, 0.6224182 , 0.66992328,
#        0.68629926, 0.68111927, 0.60624713, 0.64591666, 0.6686037 ,
#        0.66634155, 0.65875189, 0.67994722, 0.61971346, 0.52971117,
#        0.51217133, 0.58187988, 0.64847387, 0.684701  , 0.69873287,
#        0.69857714, 0.68540588, 0.68940561, 0.71698577, 0.70959281,
#        0.69739689, 0.71611698, 0.72525572, 0.71969871, 0.74865583,
#        0.76858894, 0.74820504, 0.76506459, 0.78107173, 0.78139138,
#        0.74773785, 0.84508393, 0.8707052 , 0.86414006, 0.86090256,
#        0.88963838, 0.86900039, 0.8260278 , 0.8801554 , 0.90999771,
#        0.9125959 , 0.91295653, 0.93847944, 0.93888106, 0.89431021,
#        0.92601305, 0.92925054, 0.90369484, 0.89098256, 0.91546456,
#        0.91399744, 0.87620484, 0.91504655, 0.94184808, 0.95322438,
#        0.93051275, 0.65308013, 0.60037047, 0.41433349, 0.54508721,
#        0.63621238, 0.66117796, 0.67809488, 0.748705  , 0.77808832,
#        0.76689233, 0.83516655, 0.88858108, 0.92159531, 0.92334109,
#        0.89744115, 0.84873123, 0.77637532, 0.83885483, 0.88837617,
#        0.90717002, 1.04367746, 1.05900433, 1.02185103, 1.03134221,
#        1.04883286, 1.0650777 , 1.06606944, 1.07695397, 1.02343289,
#        0.91986591, 0.77687529, 0.85038686, 0.9173169 , 0.90676841,
#        0.95269982, 0.96644482, 0.87086093, 0.77156416, 0.48927939,
#        0.54717723, 0.5914858 , 0.62762278, 0.62927021, 0.88195036,
#        0.90095731])

# %%
y_test = y_test.reshape(-1, 1)
y_test_inv = scaler_y.inverse_transform(y_test)

# %%
def plot_model_rmse_and_loss(history):
    
    # Evaluate train and validation accuracies and losses
    
    train_rmse = history.history['root_mean_squared_error']
    val_rmse = history.history['val_root_mean_squared_error']
    
    train_loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    # Visualize epochs vs. train and validation accuracies and losses
    
    plt.figure(figsize=(20, 10))
    plt.subplot(1, 2, 1)
    plt.plot(train_rmse, label='Training RMSE')
    plt.plot(val_rmse, label='Validation RMSE')
    plt.legend()
    plt.title('Epochs vs. Training and Validation RMSE')
    
    plt.subplot(1, 2, 2)
    plt.plot(train_loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.legend()
    plt.title('Epochs vs. Training and Validation Loss')
    
    plt.show()

# %% [markdown]
# # **Vanila LSTM**

# %%
tf.keras.backend.clear_session()

multivariate_lstm = tf.keras.models.Sequential([
    LSTM(100, input_shape=input_shape, 
         return_sequences=True),
    Flatten(),
    Dense(200, activation='relu'),
    Dropout(0.1),
    Dense(1)
])

model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
                   'multivariate_lstm.h5', monitor=('val_loss'), save_best_only=True)
optimizer = tf.keras.optimizers.Adam(lr=6e-3, amsgrad=True)

multivariate_lstm.compile(loss=loss,
                          optimizer=optimizer,
                          metrics=metric)

# %%
history = multivariate_lstm.fit(train, epochs=120,
                                validation_data=validation,
                                callbacks=[early_stopping, 
                                           model_checkpoint])
# Out:
# Epoch 1/120
# 37/37 [==============================] - 3s 35ms/step - loss: 0.0356 - root_mean_squared_error: 0.1887 - val_loss: 0.0194 - val_root_mean_squared_error: 0.1392
# Epoch 2/120
# 37/37 [==============================] - 1s 23ms/step - loss: 0.0108 - root_mean_squared_error: 0.1038 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1290
# Epoch 3/120
# 37/37 [==============================] - 1s 25ms/step - loss: 0.0096 - root_mean_squared_error: 0.0981 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1247
# Epoch 4/120
# 37/37 [==============================] - 1s 26ms/step - loss: 0.0091 - root_mean_squared_error: 0.0955 - val_loss: 0.0189 - val_root_mean_squared_error: 0.1375
# Epoch 5/120
# 37/37 [==============================] - 1s 26ms/step - loss: 0.0086 - root_mean_squared_error: 0.0927 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1222
# Epoch 6/120
# 37/37 [==============================] - 1s 26ms/step - loss: 0.0077 - root_mean_squared_error: 0.0878 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1204
# Epoch 7/120
# 37/37 [==============================] - 1s 26ms/step - loss: 0.0080 - root_mean_squared_error: 0.0897 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1159
# Epoch 8/120
# 37/37 [==============================] - 1s 22ms/step - loss: 0.0076 - root_mean_squared_error: 0.0873 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1346
# Epoch 9/120
# 37/37 [==============================] - 1s 24ms/step - loss: 0.0074 - root_mean_squared_error: 0.0861 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1149
# Epoch 10/120
# 37/37 [==============================] - 1s 24ms/step - loss: 0.0075 - root_mean_squared_error: 0.0864 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1250
# Epoch 11/120
# 37/37 [==============================] - 1s 22ms/step - loss: 0.0077 - root_mean_squared_error: 0.0876 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1178
# Epoch 12/120
# 37/37 [==============================] - 1s 21ms/step - loss: 0.0069 - root_mean_squared_error: 0.0833 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1300
# Epoch 13/120
# 37/37 [==============================] - 1s 22ms/step - loss: 0.0068 - root_mean_squared_error: 0.0822 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1126
# Epoch 14/120
# 37/37 [==============================] - 1s 22ms/step - loss: 0.0066 - root_mean_squared_error: 0.0814 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1262
# Epoch 15/120
# 37/37 [==============================] - 1s 22ms/step - loss: 0.0068 - root_mean_squared_error: 0.0827 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1137
# Epoch 16/120
# 37/37 [==============================] - 1s 23ms/step - loss: 0.0063 - root_mean_squared_error: 0.0797 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1104
# Epoch 17/120
# 37/37 [==============================] - 1s 23ms/step - loss: 0.0063 - root_mean_squared_error: 0.0793 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1106
# Epoch 18/120
# 37/37 [==============================] - 1s 23ms/step - loss: 0.0062 - root_mean_squared_error: 0.0786 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1091
# Epoch 19/120
# 37/37 [==============================] - 1s 23ms/step - loss: 0.0061 - root_mean_squared_error: 0.0781 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1083
# Epoch 20/120
# 37/37 [==============================] - 1s 22ms/step - loss: 0.0058 - root_mean_squared_error: 0.0764 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1170
# Epoch 21/120
# 37/37 [==============================] - 1s 23ms/step - loss: 0.0057 - root_mean_squared_error: 0.0752 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1082
# Epoch 22/120
# 37/37 [==============================] - 1s 22ms/step - loss: 0.0057 - root_mean_squared_error: 0.0757 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1119
# Epoch 23/120
# 37/37 [==============================] - 1s 24ms/step - loss: 0.0056 - root_mean_squared_error: 0.0749 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1020
# Epoch 24/120
# 37/37 [==============================] - 1s 22ms/step - loss: 0.0059 - root_mean_squared_error: 0.0767 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1085
# Epoch 25/120
# 37/37 [==============================] - 1s 21ms/step - loss: 0.0056 - root_mean_squared_error: 0.0749 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1121
# Epoch 26/120
# 37/37 [==============================] - 1s 23ms/step - loss: 0.0054 - root_mean_squared_error: 0.0735 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1005
# Epoch 27/120
# 37/37 [==============================] - 1s 22ms/step - loss: 0.0058 - root_mean_squared_error: 0.0764 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1156
# Epoch 28/120
# 37/37 [==============================] - 1s 23ms/step - loss: 0.0056 - root_mean_squared_error: 0.0749 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0983
# Epoch 29/120
# 37/37 [==============================] - 1s 21ms/step - loss: 0.0060 - root_mean_squared_error: 0.0772 - val_loss: 0.0153 - val_root_mean_squared_error: 0.1237
# Epoch 30/120
# 37/37 [==============================] - 1s 22ms/step - loss: 0.0056 - root_mean_squared_error: 0.0751 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1035
# Epoch 31/120
# 37/37 [==============================] - 1s 23ms/step - loss: 0.0049 - root_mean_squared_error: 0.0703 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0981
# Epoch 32/120
# 37/37 [==============================] - 1s 23ms/step - loss: 0.0051 - root_mean_squared_error: 0.0715 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1159
# Epoch 33/120
# 37/37 [==============================] - 1s 23ms/step - loss: 0.0050 - root_mean_squared_error: 0.0706 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1009
# Epoch 34/120
# 37/37 [==============================] - 1s 23ms/step - loss: 0.0050 - root_mean_squared_error: 0.0707 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1044
# Epoch 35/120
# 37/37 [==============================] - 1s 23ms/step - loss: 0.0048 - root_mean_squared_error: 0.0690 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0969
# Epoch 36/120
# 37/37 [==============================] - 1s 22ms/step - loss: 0.0054 - root_mean_squared_error: 0.0732 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1150
# Epoch 37/120
# 37/37 [==============================] - 1s 22ms/step - loss: 0.0049 - root_mean_squared_error: 0.0696 - val_loss: 0.0138 - val_root_mean_squared_error: 0.1175
# Epoch 38/120
# 37/37 [==============================] - 1s 22ms/step - loss: 0.0048 - root_mean_squared_error: 0.0691 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0995
# Epoch 39/120
# 37/37 [==============================] - 1s 21ms/step - loss: 0.0045 - root_mean_squared_error: 0.0675 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0989
# Epoch 40/120
# 37/37 [==============================] - 1s 22ms/step - loss: 0.0048 - root_mean_squared_error: 0.0692 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0964
# Epoch 41/120
# 37/37 [==============================] - 1s 22ms/step - loss: 0.0048 - root_mean_squared_error: 0.0690 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1060
# Epoch 42/120
# 37/37 [==============================] - 1s 22ms/step - loss: 0.0046 - root_mean_squared_error: 0.0680 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0983
# Epoch 43/120
# 37/37 [==============================] - 1s 22ms/step - loss: 0.0046 - root_mean_squared_error: 0.0679 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1052
# Epoch 44/120
# 37/37 [==============================] - 1s 23ms/step - loss: 0.0047 - root_mean_squared_error: 0.0685 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0947
# Epoch 45/120
# 37/37 [==============================] - 1s 22ms/step - loss: 0.0050 - root_mean_squared_error: 0.0706 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1014
# Epoch 46/120
# 37/37 [==============================] - 1s 23ms/step - loss: 0.0043 - root_mean_squared_error: 0.0656 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0973
# Epoch 47/120
# 37/37 [==============================] - 1s 22ms/step - loss: 0.0044 - root_mean_squared_error: 0.0662 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1001
# Epoch 48/120
# 37/37 [==============================] - 1s 22ms/step - loss: 0.0045 - root_mean_squared_error: 0.0671 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0975
# Epoch 49/120
# 37/37 [==============================] - 1s 22ms/step - loss: 0.0045 - root_mean_squared_error: 0.0668 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0978
# Epoch 50/120
# 37/37 [==============================] - 1s 23ms/step - loss: 0.0046 - root_mean_squared_error: 0.0679 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0943
# Epoch 51/120
# 37/37 [==============================] - 1s 22ms/step - loss: 0.0045 - root_mean_squared_error: 0.0670 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1002
# Epoch 52/120
# 37/37 [==============================] - 1s 21ms/step - loss: 0.0044 - root_mean_squared_error: 0.0662 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0969
# Epoch 53/120
# 37/37 [==============================] - 1s 21ms/step - loss: 0.0043 - root_mean_squared_error: 0.0659 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1041
# Epoch 54/120
# 37/37 [==============================] - 1s 22ms/step - loss: 0.0048 - root_mean_squared_error: 0.0696 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1018
# Epoch 55/120
# 37/37 [==============================] - 1s 22ms/step - loss: 0.0045 - root_mean_squared_error: 0.0674 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1258
# Epoch 56/120
# 37/37 [==============================] - 1s 22ms/step - loss: 0.0048 - root_mean_squared_error: 0.0694 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0951
# Epoch 57/120
# 37/37 [==============================] - 1s 22ms/step - loss: 0.0043 - root_mean_squared_error: 0.0658 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0944
# Epoch 58/120
# 37/37 [==============================] - 1s 21ms/step - loss: 0.0043 - root_mean_squared_error: 0.0656 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0951
# Epoch 59/120
# 37/37 [==============================] - 1s 22ms/step - loss: 0.0040 - root_mean_squared_error: 0.0635 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0976
# Epoch 60/120
# 37/37 [==============================] - 1s 23ms/step - loss: 0.0042 - root_mean_squared_error: 0.0644 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0970

# %%
plot_model_rmse_and_loss(history)

# %%
multivariate_lstm = tf.keras.models.load_model('multivariate_lstm.h5')

forecast = multivariate_lstm.predict(X_test)
lstm_forecast = scaler_y.inverse_transform(forecast)

rmse_lstm = sqrt(mean_squared_error(y_test_inv,
                                    lstm_forecast))
print('RMSE of day ahead power demand LSTM forecast: {}'
      .format(round(rmse_lstm, 3)))
# Out:
# 6/6 [==============================] - 0s 5ms/step
# RMSE of day ahead power demand LSTM forecast: 11.961

# %%
merged_df.index[1368:1529]
# Out:
# DatetimeIndex(['2022-09-30', '2022-10-01', '2022-10-02', '2022-10-03',
#                '2022-10-04', '2022-10-05', '2022-10-06', '2022-10-07',
#                '2022-10-08', '2022-10-09',
#                ...
#                '2023-02-28', '2023-03-01', '2023-03-02', '2023-03-03',
#                '2023-03-04', '2023-03-05', '2023-03-06', '2023-03-07',
#                '2023-03-08', '2023-03-09'],
#               dtype='datetime64[ns]', length=161, freq='D')

# %%
len(lstm_forecast)
# Out:
# 161

# %%
# Create arrays for the x-axis (dates)
dates_true = merged_df.index[:1559]
dates_forecasted = merged_df.index[1368:1529]
dates_unseen = merged_df.index[1529:1559]

# %%
X_test2 = X[1530:1558,:].reshape(1,past_history,n_features)

# %%
multivariate_lstm = tf.keras.models.load_model('multivariate_lstm.h5')

forecast_unseen = multivariate_lstm.predict(X_test2)
lstm_forecast_unseen = scaler_y.inverse_transform(forecast_unseen)
# Out:
# 1/1 [==============================] - 0s 326ms/step

# %%
lstm_forecast_unseen
# Out:
# array([[1403.5891]], dtype=float32)

# %%
len(dates_forecasted)
# Out:
# 161

# %%
# Extend the index to add one more day for unseen predictions
last_date = merged_df.index[-1]
future_date = last_date + pd.DateOffset(days=1)
extended_index = merged_df.index.append(pd.Index([future_date]))

# %%
merged_df.tail(4)
# Out:
#             Energy Required (MU)       Tmax       Tmin      Rain
# 2023-04-04               193.000  35.972310  25.309858  0.392332
# 2023-04-05               193.201  33.934335  25.928193  2.541572
# 2023-04-06               224.030  38.145824  27.398606  0.000000
# 2023-04-07               226.349  39.622750  27.568079  0.000000

# %%
extended_index[-1:]
# Out:
# DatetimeIndex(['2023-04-08'], dtype='datetime64[ns]', freq=None)

# %%
import matplotlib.pyplot as plt

# Assuming merged_df is your DataFrame with the date column set as the index
true_values = merged_df['Energy Required (MU)'].values
 # Replace X_test with your test data



# Plotting the true values and forecasted values
plt.figure(figsize=(20, 6))
plt.plot(dates_true, true_values[:1559], label='True Values')
plt.plot(dates_forecasted, lstm_forecast, label='Forecasted Values')  # Adjust the number of forecasted values
plt.xlabel('Date')
plt.ylabel('Energy Demand')
plt.title('True vs. Forecasted Energy Demand')
plt.legend()

'''# Adding another plot for unseen predictions
plt.figure(figsize=(12, 6))
plt.plot(dates_unseen, forecasted_values[161:], label='Unseen Predictions')  # Adjust the number of forecasted values
plt.xlabel('Date')
plt.ylabel('Energy Demand')
plt.title('Unseen Predictions')
plt.legend()'''

plt.show()

# %% [markdown]
# # **Stacked LSTM**

# %%
tf.keras.backend.clear_session()

from tensorflow.keras.layers import LSTM, Dense, Dropout, Flatten, LeakyReLU

multivariate_stacked_lstm = tf.keras.models.Sequential([
    LSTM(250, input_shape=input_shape, return_sequences=True),
    LSTM(200, return_sequences=True),
    LSTM(150, return_sequences=True),
    LSTM(100, return_sequences=True),
    LSTM(50),
    Flatten(),
    Dense(150),
    LeakyReLU(),
    Dropout(0.2),
    Dense(1)
])


model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
                   'multivariate_stacked_lstm.h5', save_best_only=True)
optimizer = tf.keras.optimizers.Adam(lr=3e-3, amsgrad=True)

multivariate_stacked_lstm.compile(loss=loss,
                                  optimizer=optimizer,
                                  metrics=metric)

# %%
history = multivariate_stacked_lstm.fit(train, epochs=120,
                                validation_data=validation,
                                callbacks=[early_stopping, 
                                           model_checkpoint])
# Out:
# Epoch 1/120
# 37/37 [==============================] - 15s 193ms/step - loss: 0.0462 - root_mean_squared_error: 0.2024 - val_loss: 0.0188 - val_root_mean_squared_error: 0.1370
# Epoch 2/120
# 37/37 [==============================] - 6s 149ms/step - loss: 0.0180 - root_mean_squared_error: 0.1342 - val_loss: 0.0208 - val_root_mean_squared_error: 0.1443
# Epoch 3/120
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0148 - root_mean_squared_error: 0.1215 - val_loss: 0.0219 - val_root_mean_squared_error: 0.1481
# Epoch 4/120
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0132 - root_mean_squared_error: 0.1147 - val_loss: 0.0224 - val_root_mean_squared_error: 0.1498
# Epoch 5/120
# 37/37 [==============================] - 6s 149ms/step - loss: 0.0127 - root_mean_squared_error: 0.1129 - val_loss: 0.0251 - val_root_mean_squared_error: 0.1585
# Epoch 6/120
# 37/37 [==============================] - 6s 149ms/step - loss: 0.0131 - root_mean_squared_error: 0.1145 - val_loss: 0.0185 - val_root_mean_squared_error: 0.1361
# Epoch 7/120
# 37/37 [==============================] - 5s 148ms/step - loss: 0.0136 - root_mean_squared_error: 0.1168 - val_loss: 0.0244 - val_root_mean_squared_error: 0.1562
# Epoch 8/120
# 37/37 [==============================] - 5s 146ms/step - loss: 0.0133 - root_mean_squared_error: 0.1155 - val_loss: 0.0216 - val_root_mean_squared_error: 0.1471
# Epoch 9/120
# 37/37 [==============================] - 6s 161ms/step - loss: 0.0105 - root_mean_squared_error: 0.1026 - val_loss: 0.0216 - val_root_mean_squared_error: 0.1469
# Epoch 10/120
# 37/37 [==============================] - 6s 169ms/step - loss: 0.0100 - root_mean_squared_error: 0.1000 - val_loss: 0.0214 - val_root_mean_squared_error: 0.1464
# Epoch 11/120
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0107 - root_mean_squared_error: 0.1033 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1529
# Epoch 12/120
# 37/37 [==============================] - 6s 163ms/step - loss: 0.0101 - root_mean_squared_error: 0.1004 - val_loss: 0.0199 - val_root_mean_squared_error: 0.1412
# Epoch 13/120
# 37/37 [==============================] - 6s 160ms/step - loss: 0.0093 - root_mean_squared_error: 0.0966 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1348
# Epoch 14/120
# 37/37 [==============================] - 6s 160ms/step - loss: 0.0097 - root_mean_squared_error: 0.0984 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1460
# Epoch 15/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0097 - root_mean_squared_error: 0.0983 - val_loss: 0.0189 - val_root_mean_squared_error: 0.1373
# Epoch 16/120
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0102 - root_mean_squared_error: 0.1012 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1344
# Epoch 17/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0088 - root_mean_squared_error: 0.0940 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1276
# Epoch 18/120
# 37/37 [==============================] - 6s 149ms/step - loss: 0.0085 - root_mean_squared_error: 0.0922 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1263
# Epoch 19/120
# 37/37 [==============================] - 5s 144ms/step - loss: 0.0087 - root_mean_squared_error: 0.0935 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1294
# Epoch 20/120
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0085 - root_mean_squared_error: 0.0919 - val_loss: 0.0151 - val_root_mean_squared_error: 0.1230
# Epoch 21/120
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0083 - root_mean_squared_error: 0.0913 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1193
# Epoch 22/120
# 37/37 [==============================] - 5s 148ms/step - loss: 0.0085 - root_mean_squared_error: 0.0923 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1286
# Epoch 23/120
# 37/37 [==============================] - 5s 145ms/step - loss: 0.0076 - root_mean_squared_error: 0.0874 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1165
# Epoch 24/120
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0075 - root_mean_squared_error: 0.0865 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1212
# Epoch 25/120
# 37/37 [==============================] - 6s 149ms/step - loss: 0.0074 - root_mean_squared_error: 0.0862 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1225
# Epoch 26/120
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0071 - root_mean_squared_error: 0.0845 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1128
# Epoch 27/120
# 37/37 [==============================] - 5s 146ms/step - loss: 0.0075 - root_mean_squared_error: 0.0865 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1119
# Epoch 28/120
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0068 - root_mean_squared_error: 0.0824 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1201
# Epoch 29/120
# 37/37 [==============================] - 6s 149ms/step - loss: 0.0064 - root_mean_squared_error: 0.0798 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1045
# Epoch 30/120
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0067 - root_mean_squared_error: 0.0818 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1042
# Epoch 31/120
# 37/37 [==============================] - 5s 148ms/step - loss: 0.0062 - root_mean_squared_error: 0.0789 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1039
# Epoch 32/120
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0059 - root_mean_squared_error: 0.0767 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0953
# Epoch 33/120
# 37/37 [==============================] - 5s 145ms/step - loss: 0.0062 - root_mean_squared_error: 0.0785 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0959
# Epoch 34/120
# 37/37 [==============================] - 5s 146ms/step - loss: 0.0062 - root_mean_squared_error: 0.0790 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1024
# Epoch 35/120
# 37/37 [==============================] - 5s 142ms/step - loss: 0.0062 - root_mean_squared_error: 0.0789 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0986
# Epoch 36/120
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0056 - root_mean_squared_error: 0.0750 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0962
# Epoch 37/120
# 37/37 [==============================] - 5s 146ms/step - loss: 0.0055 - root_mean_squared_error: 0.0739 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0911
# Epoch 38/120
# 37/37 [==============================] - 5s 145ms/step - loss: 0.0051 - root_mean_squared_error: 0.0716 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0919
# Epoch 39/120
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0051 - root_mean_squared_error: 0.0713 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0908
# Epoch 40/120
# 37/37 [==============================] - 5s 149ms/step - loss: 0.0054 - root_mean_squared_error: 0.0733 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0977
# Epoch 41/120
# 37/37 [==============================] - 5s 143ms/step - loss: 0.0051 - root_mean_squared_error: 0.0713 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0935
# Epoch 42/120
# 37/37 [==============================] - 5s 145ms/step - loss: 0.0052 - root_mean_squared_error: 0.0719 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1031
# Epoch 43/120
# 37/37 [==============================] - 5s 146ms/step - loss: 0.0052 - root_mean_squared_error: 0.0724 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0919
# Epoch 44/120
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0051 - root_mean_squared_error: 0.0713 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0952
# Epoch 45/120
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0052 - root_mean_squared_error: 0.0718 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0933
# Epoch 46/120
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0048 - root_mean_squared_error: 0.0696 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0952
# Epoch 47/120
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0050 - root_mean_squared_error: 0.0705 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0969
# Epoch 48/120
# 37/37 [==============================] - 5s 146ms/step - loss: 0.0049 - root_mean_squared_error: 0.0701 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0979
# Epoch 49/120
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0051 - root_mean_squared_error: 0.0712 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0896
# Epoch 50/120
# 37/37 [==============================] - 5s 148ms/step - loss: 0.0048 - root_mean_squared_error: 0.0696 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0946
# Epoch 51/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0049 - root_mean_squared_error: 0.0703 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1007
# Epoch 52/120
# 37/37 [==============================] - 5s 148ms/step - loss: 0.0049 - root_mean_squared_error: 0.0701 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0944
# Epoch 53/120
# 37/37 [==============================] - 5s 149ms/step - loss: 0.0052 - root_mean_squared_error: 0.0721 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0935
# Epoch 54/120
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0047 - root_mean_squared_error: 0.0686 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0947
# Epoch 55/120
# 37/37 [==============================] - 5s 145ms/step - loss: 0.0049 - root_mean_squared_error: 0.0700 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0937
# Epoch 56/120
# 37/37 [==============================] - 5s 144ms/step - loss: 0.0047 - root_mean_squared_error: 0.0688 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0951
# Epoch 57/120
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0049 - root_mean_squared_error: 0.0698 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0947
# Epoch 58/120
# 37/37 [==============================] - 5s 148ms/step - loss: 0.0044 - root_mean_squared_error: 0.0662 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0950
# Epoch 59/120
# 37/37 [==============================] - 5s 148ms/step - loss: 0.0046 - root_mean_squared_error: 0.0680 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0989

# %%
plot_model_rmse_and_loss(history)

# %%
multivariate_stacked_lstm = tf.keras.models.load_model('multivariate_stacked_lstm.h5')

forecast = multivariate_stacked_lstm.predict(X_test)
multivariate_stacked_lstm_forecast = scaler_y.inverse_transform(forecast)

rmse_mult_stacked_lstm = sqrt(mean_squared_error(y_test_inv, 
                                                 multivariate_stacked_lstm_forecast))
print('RMSE of day ahead power demand multivariate Stacked LSTM forecast: {}'
      .format(round(rmse_mult_stacked_lstm, 3)))
# Out:
# 6/6 [==============================] - 2s 40ms/step
# RMSE of day ahead power demand multivariate Stacked LSTM forecast: 12.067

# %%
# Create arrays for the x-axis (dates)
dates_true = merged_df.index[:1559]
dates_forecasted = merged_df.index[1368:1529]
dates_unseen = merged_df.index[1529:1559]

# %%
n_features = 4

# %%
X_test2 = X[1530:1558,:].reshape(1,past_history,n_features)

# %%
multivariate_lstm = tf.keras.models.load_model('multivariate_lstm.h5')

forecast_unseen = multivariate_lstm.predict(X_test2)
lstm_forecast_unseen = scaler_y.inverse_transform(forecast_unseen)
# Out:
# 1/1 [==============================] - 0s 310ms/step

# %%
# Extend the index to add one more day for unseen predictions
last_date = merged_df.index[-1]
future_date = last_date + pd.DateOffset(days=1)
extended_index = merged_df.index.append(pd.Index([future_date]))

# %%
import matplotlib.pyplot as plt

# Assuming merged_df is your DataFrame with the date column set as the index
true_values = merged_df['Energy Required (MU)'].values
 # Replace X_test with your test data



# Plotting the true values and forecasted values
plt.figure(figsize=(20, 6))
plt.plot(dates_true, true_values[:1559], label='True Values')
plt.plot(dates_forecasted, multivariate_stacked_lstm_forecast, label='Forecasted Values')  # Adjust the number of forecasted values
plt.xlabel('Date')
plt.ylabel('Energy Demand')
plt.title('True vs. Forecasted Energy Demand')
plt.legend()

'''# Adding another plot for unseen predictions
plt.figure(figsize=(12, 6))
plt.plot(dates_unseen, forecasted_values[161:], label='Unseen Predictions')  # Adjust the number of forecasted values
plt.xlabel('Date')
plt.ylabel('Energy Demand')
plt.title('Unseen Predictions')
plt.legend()'''

plt.show()

# %% [markdown]
# # **CNN**

# %%
tf.keras.backend.clear_session()

multivariate_cnn = tf.keras.models.Sequential([
    Conv1D(filters=48, kernel_size=2,
           strides=1, padding='causal',
           activation='relu', 
           input_shape=input_shape),
    Flatten(),
    Dense(48, activation='relu'),
    Dense(1)
])

model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
                   'multivariate_cnn.h5', save_best_only=True)
optimizer = tf.keras.optimizers.Adam(lr=6e-3, amsgrad=True)

multivariate_cnn.compile(loss=loss,
                          optimizer=optimizer,
                          metrics=metric)

# %%
history = multivariate_cnn.fit(train, epochs=120,
                               validation_data=validation,
                               callbacks=[early_stopping, 
                                          model_checkpoint])
# Out:
# Epoch 1/120
# 37/37 [==============================] - 1s 9ms/step - loss: 0.0249 - root_mean_squared_error: 0.1508 - val_loss: 0.0190 - val_root_mean_squared_error: 0.1377
# Epoch 2/120
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0085 - root_mean_squared_error: 0.0924 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1277
# Epoch 3/120
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0071 - root_mean_squared_error: 0.0844 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1221
# Epoch 4/120
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0075 - root_mean_squared_error: 0.0864 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1296
# Epoch 5/120
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0066 - root_mean_squared_error: 0.0815 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1164
# Epoch 6/120
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0061 - root_mean_squared_error: 0.0780 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1285
# Epoch 7/120
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0061 - root_mean_squared_error: 0.0778 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1139
# Epoch 8/120
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0056 - root_mean_squared_error: 0.0745 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1162
# Epoch 9/120
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0057 - root_mean_squared_error: 0.0754 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1109
# Epoch 10/120
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0057 - root_mean_squared_error: 0.0754 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1187
# Epoch 11/120
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0051 - root_mean_squared_error: 0.0714 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1115
# Epoch 12/120
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0044 - root_mean_squared_error: 0.0664 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1038
# Epoch 13/120
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0049 - root_mean_squared_error: 0.0704 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1124
# Epoch 14/120
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0052 - root_mean_squared_error: 0.0723 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1082
# Epoch 15/120
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0045 - root_mean_squared_error: 0.0667 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1065
# Epoch 16/120
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0043 - root_mean_squared_error: 0.0653 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1043
# Epoch 17/120
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0040 - root_mean_squared_error: 0.0629 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1093
# Epoch 18/120
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0039 - root_mean_squared_error: 0.0623 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1067
# Epoch 19/120
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0037 - root_mean_squared_error: 0.0611 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1063
# Epoch 20/120
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0036 - root_mean_squared_error: 0.0604 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1074
# Epoch 21/120
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0038 - root_mean_squared_error: 0.0617 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1029
# Epoch 22/120
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0035 - root_mean_squared_error: 0.0595 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1038
# Epoch 23/120
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0034 - root_mean_squared_error: 0.0580 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1068
# Epoch 24/120
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0034 - root_mean_squared_error: 0.0580 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1027
# Epoch 25/120
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0034 - root_mean_squared_error: 0.0582 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1224
# Epoch 26/120
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0034 - root_mean_squared_error: 0.0582 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1034
# Epoch 27/120
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0035 - root_mean_squared_error: 0.0594 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1009
# Epoch 28/120
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0033 - root_mean_squared_error: 0.0578 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1038
# Epoch 29/120
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0032 - root_mean_squared_error: 0.0569 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1004
# Epoch 30/120
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0030 - root_mean_squared_error: 0.0550 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1015
# Epoch 31/120
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0032 - root_mean_squared_error: 0.0564 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1047
# Epoch 32/120
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0030 - root_mean_squared_error: 0.0550 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1023
# Epoch 33/120
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0028 - root_mean_squared_error: 0.0532 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1035
# Epoch 34/120
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0032 - root_mean_squared_error: 0.0562 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1055
# Epoch 35/120
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0028 - root_mean_squared_error: 0.0526 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1025
# Epoch 36/120
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0028 - root_mean_squared_error: 0.0531 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1107
# Epoch 37/120
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0026 - root_mean_squared_error: 0.0507 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1047
# Epoch 38/120
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0026 - root_mean_squared_error: 0.0510 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1039
# Epoch 39/120
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0025 - root_mean_squared_error: 0.0502 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1043

# %%
plot_model_rmse_and_loss(history)

# %%
multivariate_cnn = tf.keras.models.load_model('multivariate_cnn.h5')

forecast = multivariate_cnn.predict(X_test)
multivariate_cnn_forecast = scaler_y.inverse_transform(forecast)

rmse_mult_cnn = sqrt(mean_squared_error(y_test_inv,
                                        multivariate_cnn_forecast))
print('RMSE of day ahead electricity price multivariate CNN forecast: {}'
      .format(round(rmse_mult_cnn, 3)))
# Out:
# 6/6 [==============================] - 0s 3ms/step
# RMSE of day ahead electricity price multivariate CNN forecast: 12.915

# %%
# Create arrays for the x-axis (dates)
dates_true = merged_df.index[:1559]
dates_forecasted = merged_df.index[1368:1529]
dates_unseen = merged_df.index[1529:1559]

X_test2 = X[1530:1558,:].reshape(1,28,4)

multivariate_lstm = tf.keras.models.load_model('multivariate_lstm.h5')

forecast_unseen = multivariate_lstm.predict(X_test2)
lstm_forecast_unseen = scaler_y.inverse_transform(forecast_unseen)


# Extend the index to add one more day for unseen predictions
last_date = merged_df.index[-1]
future_date = last_date + pd.DateOffset(days=1)
extended_index = merged_df.index.append(pd.Index([future_date]))

import matplotlib.pyplot as plt

# Assuming merged_df is your DataFrame with the date column set as the index
true_values = merged_df['Energy Required (MU)'].values
 # Replace X_test with your test data



# Plotting the true values and forecasted values
plt.figure(figsize=(20, 6))
plt.plot(dates_true, true_values[:1559], label='True Values')
plt.plot(dates_forecasted, multivariate_cnn_forecast, label='Forecasted Values')  # Adjust the number of forecasted values
plt.xlabel('Date')
plt.ylabel('Energy Demand')
plt.title('True vs. Forecasted Energy Demand')
plt.legend()

'''# Adding another plot for unseen predictions
plt.figure(figsize=(12, 6))
plt.plot(dates_unseen, forecasted_values[161:], label='Unseen Predictions')  # Adjust the number of forecasted values
plt.xlabel('Date')
plt.ylabel('Energy Demand')
plt.title('Unseen Predictions')
plt.legend()'''

plt.show()
# Out:
# 1/1 [==============================] - 0s 358ms/step

# %% [markdown]
# # **CNN- LSTM**

# %%
tf.keras.backend.clear_session()

multivariate_cnn_lstm = tf.keras.models.Sequential([
    Conv1D(filters=100, kernel_size=2,
           strides=1, padding='causal',
           activation='relu',
           input_shape=input_shape),
    Conv1D(filters=100, kernel_size=2,
           strides=1, padding='causal',
           activation='relu'),
    Conv1D(filters=100, kernel_size=2,
           strides=1, padding='causal',
           activation='relu'),
    LSTM(150, return_sequences=True),
    LSTM(100, return_sequences=True),
    LSTM(50),
    Flatten(),
    Dense(100),
    LeakyReLU(),
    Dropout(0.2),
    Dense(1)
])

model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
                   'multivariate_cnn_lstm.h5', save_best_only=True)
optimizer = tf.keras.optimizers.Adam(lr=4e-3, amsgrad=True)

multivariate_cnn_lstm.compile(loss=loss,
                          optimizer=optimizer,
                          metrics=metric)

# %%
history = multivariate_cnn_lstm.fit(train, epochs=120,
                                    validation_data=validation,
                                    callbacks=[early_stopping, 
                                               model_checkpoint])
# Out:
# Epoch 1/120
# 37/37 [==============================] - 11s 120ms/step - loss: 0.0365 - root_mean_squared_error: 0.1811 - val_loss: 0.0198 - val_root_mean_squared_error: 0.1406
# Epoch 2/120
# 37/37 [==============================] - 3s 80ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186 - val_loss: 0.0288 - val_root_mean_squared_error: 0.1697
# Epoch 3/120
# 37/37 [==============================] - 3s 78ms/step - loss: 0.0142 - root_mean_squared_error: 0.1193 - val_loss: 0.0283 - val_root_mean_squared_error: 0.1683
# Epoch 4/120
# 37/37 [==============================] - 3s 74ms/step - loss: 0.0121 - root_mean_squared_error: 0.1101 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1449
# Epoch 5/120
# 37/37 [==============================] - 3s 74ms/step - loss: 0.0106 - root_mean_squared_error: 0.1030 - val_loss: 0.0211 - val_root_mean_squared_error: 0.1454
# Epoch 6/120
# 37/37 [==============================] - 3s 78ms/step - loss: 0.0106 - root_mean_squared_error: 0.1029 - val_loss: 0.0194 - val_root_mean_squared_error: 0.1394
# Epoch 7/120
# 37/37 [==============================] - 3s 82ms/step - loss: 0.0103 - root_mean_squared_error: 0.1014 - val_loss: 0.0189 - val_root_mean_squared_error: 0.1376
# Epoch 8/120
# 37/37 [==============================] - 3s 79ms/step - loss: 0.0104 - root_mean_squared_error: 0.1020 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1330
# Epoch 9/120
# 37/37 [==============================] - 3s 77ms/step - loss: 0.0089 - root_mean_squared_error: 0.0944 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1255
# Epoch 10/120
# 37/37 [==============================] - 3s 77ms/step - loss: 0.0096 - root_mean_squared_error: 0.0979 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1280
# Epoch 11/120
# 37/37 [==============================] - 3s 77ms/step - loss: 0.0082 - root_mean_squared_error: 0.0908 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1260
# Epoch 12/120
# 37/37 [==============================] - 3s 74ms/step - loss: 0.0083 - root_mean_squared_error: 0.0913 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1121
# Epoch 13/120
# 37/37 [==============================] - 3s 72ms/step - loss: 0.0077 - root_mean_squared_error: 0.0875 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1191
# Epoch 14/120
# 37/37 [==============================] - 3s 75ms/step - loss: 0.0077 - root_mean_squared_error: 0.0879 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1067
# Epoch 15/120
# 37/37 [==============================] - 3s 78ms/step - loss: 0.0071 - root_mean_squared_error: 0.0843 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1068
# Epoch 16/120
# 37/37 [==============================] - 3s 76ms/step - loss: 0.0067 - root_mean_squared_error: 0.0819 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1068
# Epoch 17/120
# 37/37 [==============================] - 3s 77ms/step - loss: 0.0065 - root_mean_squared_error: 0.0804 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0995
# Epoch 18/120
# 37/37 [==============================] - 3s 77ms/step - loss: 0.0068 - root_mean_squared_error: 0.0825 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0974
# Epoch 19/120
# 37/37 [==============================] - 3s 78ms/step - loss: 0.0063 - root_mean_squared_error: 0.0794 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1013
# Epoch 20/120
# 37/37 [==============================] - 3s 77ms/step - loss: 0.0060 - root_mean_squared_error: 0.0774 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0949
# Epoch 21/120
# 37/37 [==============================] - 3s 77ms/step - loss: 0.0058 - root_mean_squared_error: 0.0763 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1064
# Epoch 22/120
# 37/37 [==============================] - 3s 78ms/step - loss: 0.0055 - root_mean_squared_error: 0.0740 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0971
# Epoch 23/120
# 37/37 [==============================] - 3s 79ms/step - loss: 0.0057 - root_mean_squared_error: 0.0755 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0935
# Epoch 24/120
# 37/37 [==============================] - 3s 83ms/step - loss: 0.0057 - root_mean_squared_error: 0.0752 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1107
# Epoch 25/120
# 37/37 [==============================] - 3s 83ms/step - loss: 0.0057 - root_mean_squared_error: 0.0752 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0920
# Epoch 26/120
# 37/37 [==============================] - 3s 81ms/step - loss: 0.0052 - root_mean_squared_error: 0.0722 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0992
# Epoch 27/120
# 37/37 [==============================] - 3s 77ms/step - loss: 0.0059 - root_mean_squared_error: 0.0768 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1065
# Epoch 28/120
# 37/37 [==============================] - 3s 79ms/step - loss: 0.0056 - root_mean_squared_error: 0.0751 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0995
# Epoch 29/120
# 37/37 [==============================] - 3s 75ms/step - loss: 0.0051 - root_mean_squared_error: 0.0712 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0940
# Epoch 30/120
# 37/37 [==============================] - 3s 85ms/step - loss: 0.0051 - root_mean_squared_error: 0.0712 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1146
# Epoch 31/120
# 37/37 [==============================] - 3s 82ms/step - loss: 0.0050 - root_mean_squared_error: 0.0710 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0945
# Epoch 32/120
# 37/37 [==============================] - 3s 84ms/step - loss: 0.0050 - root_mean_squared_error: 0.0710 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0921
# Epoch 33/120
# 37/37 [==============================] - 3s 78ms/step - loss: 0.0048 - root_mean_squared_error: 0.0696 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0975
# Epoch 34/120
# 37/37 [==============================] - 3s 82ms/step - loss: 0.0052 - root_mean_squared_error: 0.0722 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0951
# Epoch 35/120
# 37/37 [==============================] - 3s 77ms/step - loss: 0.0054 - root_mean_squared_error: 0.0732 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0993

# %%
plot_model_rmse_and_loss(history)

# %%
multivariate_cnn_lstm = tf.keras.models.load_model('multivariate_cnn_lstm.h5')

forecast = multivariate_cnn_lstm.predict(X_test)
multivariate_cnn_lstm_forecast = scaler_y.inverse_transform(forecast)

rmse_mult_cnn_lstm = sqrt(mean_squared_error(y_test_inv, 
                                             multivariate_cnn_lstm_forecast))
print('RMSE of day-ahead power demand  multivariate CNN-`LSTM forecast: {}'
      .format(round(rmse_mult_cnn_lstm, 3)))
# Out:
# 6/6 [==============================] - 1s 20ms/step
# RMSE of day-ahead power demand  multivariate CNN-`LSTM forecast: 11.032

# %%
# Create arrays for the x-axis (dates)
dates_true = merged_df.index[:1559]
dates_forecasted = merged_df.index[1368:1529]
dates_unseen = merged_df.index[1529:1559]

X_test2 = X[1530:1558,:].reshape(1,28,4)

multivariate_lstm = tf.keras.models.load_model('multivariate_lstm.h5')

forecast_unseen = multivariate_lstm.predict(X_test2)
lstm_forecast_unseen = scaler_y.inverse_transform(forecast_unseen)


# Extend the index to add one more day for unseen predictions
last_date = merged_df.index[-1]
future_date = last_date + pd.DateOffset(days=1)
extended_index = merged_df.index.append(pd.Index([future_date]))

import matplotlib.pyplot as plt

# Assuming merged_df is your DataFrame with the date column set as the index
true_values = merged_df['Energy Required (MU)'].values
 # Replace X_test with your test data



# Plotting the true values and forecasted values
plt.figure(figsize=(20, 6))
plt.plot(dates_true, y[:1559], label='True Values')
plt.plot(dates_forecasted, multivariate_cnn_lstm_forecast, label='Forecasted Values')  # Adjust the number of forecasted values
plt.xlabel('Date')
plt.ylabel('Energy Demand')
plt.title('True vs. Forecasted Energy Demand')
plt.legend()

'''# Adding another plot for unseen predictions
plt.figure(figsize=(12, 6))
plt.plot(dates_unseen, forecasted_values[161:], label='Unseen Predictions')  # Adjust the number of forecasted values
plt.xlabel('Date')
plt.ylabel('Energy Demand')
plt.title('Unseen Predictions')
plt.legend()'''

plt.show()
# Out:
# 1/1 [==============================] - 0s 330ms/step

# %%
merged_df.tail()
# Out:
#             Energy Required (MU)       Tmax       Tmin      Rain
# 2023-04-03               188.591  35.240079  19.384070  0.000000
# 2023-04-04               193.000  35.972310  25.309858  0.392332
# 2023-04-05               193.201  33.934335  25.928193  2.541572
# 2023-04-06               224.030  38.145824  27.398606  0.000000
# 2023-04-07               226.349  39.622750  27.568079  0.000000

# %% [markdown]
# # **Time Distributed MLP**

# %%
tf.keras.backend.clear_session()

multivariate_mlp = tf.keras.models.Sequential([
    TimeDistributed(Dense(200, activation='relu'),
                    input_shape=input_shape),
    TimeDistributed(Dense(150, activation='relu')),
    TimeDistributed(Dense(100, activation='relu')),
    TimeDistributed(Dense(50, activation='relu')),
    Flatten(),
    Dense(150, activation='relu'),
    Dropout(0.1),
    Dense(1)
])

model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
                   'multivariate_mlp.h5', save_best_only=True)
optimizer = tf.keras.optimizers.Adam(lr=2e-3, amsgrad=True)

multivariate_mlp.compile(loss=loss,
                          optimizer=optimizer,
                          metrics=metric)

# %%
history = multivariate_mlp.fit(train, epochs=120,
                               validation_data=validation,
                               callbacks=[early_stopping, 
                                          model_checkpoint])

# %%
plot_model_rmse_and_loss(history)

# %%
multivariate_mlp = tf.keras.models.load_model('multivariate_mlp.h5')

forecast = multivariate_mlp.predict(X_test)
multivariate_mlp_forecast = scaler_y.inverse_transform(forecast)

rmse_mult_mlp = sqrt(mean_squared_error(y_test_inv,
                                        multivariate_mlp_forecast))
print('RMSE of day-ahead power demand multivariate MLP forecast: {}'
      .format(round(rmse_mult_mlp, 3)))

# %%
# Create arrays for the x-axis (dates)
dates_true = merged_df.index[:1559]
dates_forecasted = merged_df.index[1368:1529]
dates_unseen = merged_df.index[1529:1559]

X_test2 = X[1530:1558,:].reshape(1,28,4)

multivariate_lstm = tf.keras.models.load_model('multivariate_lstm.h5')

forecast_unseen = multivariate_lstm.predict(X_test2)
lstm_forecast_unseen = scaler_y.inverse_transform(forecast_unseen)


# Extend the index to add one more day for unseen predictions
last_date = merged_df.index[-1]
future_date = last_date + pd.DateOffset(days=1)
extended_index = merged_df.index.append(pd.Index([future_date]))

import matplotlib.pyplot as plt

# Assuming merged_df is your DataFrame with the date column set as the index
true_values = merged_df['Energy Required (MU)'].values
 # Replace X_test with your test data



# Plotting the true values and forecasted values
plt.figure(figsize=(20, 6))
plt.plot(dates_true, true_values[:1559], label='True Values')
plt.plot(dates_forecasted, multivariate_mlp_forecast, label='Forecasted Values')  # Adjust the number of forecasted values
plt.xlabel('Date')
plt.ylabel('Energy Demand')
plt.title('True vs. Forecasted Energy Demand')
plt.legend()

'''# Adding another plot for unseen predictions
plt.figure(figsize=(12, 6))
plt.plot(dates_unseen, forecasted_values[161:], label='Unseen Predictions')  # Adjust the number of forecasted values
plt.xlabel('Date')
plt.ylabel('Energy Demand')
plt.title('Unseen Predictions')
plt.legend()'''

plt.show()

# %% [markdown]
# # **Encoder Decoder**

# %%
tf.keras.backend.clear_session()

encoder_decoder = tf.keras.models.Sequential([
    LSTM(50, activation='relu', input_shape=input_shape),
    RepeatVector(past_history),
    LSTM(50, activation='relu', return_sequences=True),
    TimeDistributed(Dense(50, activation='relu')),
    Flatten(),
    Dense(25, activation='relu'),
    Dense(1)
])



model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
                   'encoder_decoder.h5', save_best_only=True)

optimizer = tf.keras.optimizers.Adam(lr=1e-3, amsgrad=True)

encoder_decoder.compile(loss=loss,
                    optimizer=optimizer,
                    metrics=metric)

# %%
history = encoder_decoder.fit(train, epochs=120,
                              validation_data=validation,
                              callbacks=[early_stopping, 
                                         model_checkpoint])
# Out:
# Epoch 1/120
# 37/37 [==============================] - 4s 41ms/step - loss: 0.0564 - root_mean_squared_error: 0.2230 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1245
# Epoch 2/120
# 37/37 [==============================] - 1s 29ms/step - loss: 0.0073 - root_mean_squared_error: 0.0856 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1327
# Epoch 3/120
# 37/37 [==============================] - 1s 29ms/step - loss: 0.0067 - root_mean_squared_error: 0.0820 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1111
# Epoch 4/120
# 37/37 [==============================] - 1s 29ms/step - loss: 0.0068 - root_mean_squared_error: 0.0823 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1157
# Epoch 5/120
# 37/37 [==============================] - 1s 30ms/step - loss: 0.0065 - root_mean_squared_error: 0.0808 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1206
# Epoch 6/120
# 37/37 [==============================] - 1s 30ms/step - loss: 0.0062 - root_mean_squared_error: 0.0788 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1036
# Epoch 7/120
# 37/37 [==============================] - 1s 31ms/step - loss: 0.0063 - root_mean_squared_error: 0.0794 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1067
# Epoch 8/120
# 37/37 [==============================] - 1s 29ms/step - loss: 0.0066 - root_mean_squared_error: 0.0815 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1198
# Epoch 9/120
# 37/37 [==============================] - 1s 30ms/step - loss: 0.0059 - root_mean_squared_error: 0.0770 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1073
# Epoch 10/120
# 37/37 [==============================] - 1s 29ms/step - loss: 0.0058 - root_mean_squared_error: 0.0761 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1091
# Epoch 11/120
# 37/37 [==============================] - 1s 29ms/step - loss: 0.0058 - root_mean_squared_error: 0.0761 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1014
# Epoch 12/120
# 37/37 [==============================] - 1s 28ms/step - loss: 0.0056 - root_mean_squared_error: 0.0747 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1037
# Epoch 13/120
# 37/37 [==============================] - 1s 27ms/step - loss: 0.0056 - root_mean_squared_error: 0.0749 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1049
# Epoch 14/120
# 37/37 [==============================] - 1s 29ms/step - loss: 0.0054 - root_mean_squared_error: 0.0738 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0996
# Epoch 15/120
# 37/37 [==============================] - 1s 27ms/step - loss: 0.0053 - root_mean_squared_error: 0.0726 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1043
# Epoch 16/120
# 37/37 [==============================] - 1s 28ms/step - loss: 0.0057 - root_mean_squared_error: 0.0755 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0995
# Epoch 17/120
# 37/37 [==============================] - 1s 29ms/step - loss: 0.0060 - root_mean_squared_error: 0.0772 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0987
# Epoch 18/120
# 37/37 [==============================] - 1s 28ms/step - loss: 0.0059 - root_mean_squared_error: 0.0771 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0997
# Epoch 19/120
# 37/37 [==============================] - 1s 27ms/step - loss: 0.0060 - root_mean_squared_error: 0.0772 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1102
# Epoch 20/120
# 37/37 [==============================] - 1s 28ms/step - loss: 0.0054 - root_mean_squared_error: 0.0736 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1001
# Epoch 21/120
# 37/37 [==============================] - 1s 28ms/step - loss: 0.0059 - root_mean_squared_error: 0.0767 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0973
# Epoch 22/120
# 37/37 [==============================] - 1s 28ms/step - loss: 0.0052 - root_mean_squared_error: 0.0719 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0962
# Epoch 23/120
# 37/37 [==============================] - 1s 27ms/step - loss: 0.0052 - root_mean_squared_error: 0.0721 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0967
# Epoch 24/120
# 37/37 [==============================] - 1s 27ms/step - loss: 0.0054 - root_mean_squared_error: 0.0734 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0950
# Epoch 25/120
# 37/37 [==============================] - 1s 28ms/step - loss: 0.0054 - root_mean_squared_error: 0.0734 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0942
# Epoch 26/120
# 37/37 [==============================] - 1s 28ms/step - loss: 0.0063 - root_mean_squared_error: 0.0796 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0964
# Epoch 27/120
# 37/37 [==============================] - 1s 30ms/step - loss: 0.0056 - root_mean_squared_error: 0.0746 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1007
# Epoch 28/120
# 37/37 [==============================] - 1s 28ms/step - loss: 0.0054 - root_mean_squared_error: 0.0732 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0969
# Epoch 29/120
# 37/37 [==============================] - 1s 27ms/step - loss: 0.0060 - root_mean_squared_error: 0.0773 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0958
# Epoch 30/120
# 37/37 [==============================] - 1s 29ms/step - loss: 0.0053 - root_mean_squared_error: 0.0730 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0977
# Epoch 31/120
# 37/37 [==============================] - 1s 29ms/step - loss: 0.0054 - root_mean_squared_error: 0.0732 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0980
# Epoch 32/120
# 37/37 [==============================] - 1s 28ms/step - loss: 0.0051 - root_mean_squared_error: 0.0717 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0984
# Epoch 33/120
# 37/37 [==============================] - 1s 28ms/step - loss: 0.0050 - root_mean_squared_error: 0.0705 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0946
# Epoch 34/120
# 37/37 [==============================] - 1s 29ms/step - loss: 0.0051 - root_mean_squared_error: 0.0711 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0929
# Epoch 35/120
# 37/37 [==============================] - 1s 30ms/step - loss: 0.0049 - root_mean_squared_error: 0.0703 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0919
# Epoch 36/120
# 37/37 [==============================] - 1s 28ms/step - loss: 0.0052 - root_mean_squared_error: 0.0722 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0967
# Epoch 37/120
# 37/37 [==============================] - 1s 27ms/step - loss: 0.0051 - root_mean_squared_error: 0.0713 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1132
# Epoch 38/120
# 37/37 [==============================] - 1s 28ms/step - loss: 0.0050 - root_mean_squared_error: 0.0708 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0921
# Epoch 39/120
# 37/37 [==============================] - 1s 30ms/step - loss: 0.0049 - root_mean_squared_error: 0.0697 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0906
# Epoch 40/120
# 37/37 [==============================] - 1s 28ms/step - loss: 0.0051 - root_mean_squared_error: 0.0714 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1050
# Epoch 41/120
# 37/37 [==============================] - 1s 29ms/step - loss: 0.0050 - root_mean_squared_error: 0.0705 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0898
# Epoch 42/120
# 37/37 [==============================] - 1s 28ms/step - loss: 0.0049 - root_mean_squared_error: 0.0700 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0901
# Epoch 43/120
# 37/37 [==============================] - 1s 28ms/step - loss: 0.0048 - root_mean_squared_error: 0.0690 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0895
# Epoch 44/120
# 37/37 [==============================] - 1s 27ms/step - loss: 0.0048 - root_mean_squared_error: 0.0692 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0899
# Epoch 45/120
# 37/37 [==============================] - 1s 26ms/step - loss: 0.0054 - root_mean_squared_error: 0.0734 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0914
# Epoch 46/120
# 37/37 [==============================] - 1s 28ms/step - loss: 0.0048 - root_mean_squared_error: 0.0690 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0894
# Epoch 47/120
# 37/37 [==============================] - 1s 26ms/step - loss: 0.0048 - root_mean_squared_error: 0.0695 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0962
# Epoch 48/120
# 37/37 [==============================] - 1s 27ms/step - loss: 0.0047 - root_mean_squared_error: 0.0682 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0897
# Epoch 49/120
# 37/37 [==============================] - 1s 26ms/step - loss: 0.0048 - root_mean_squared_error: 0.0692 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0915
# Epoch 50/120
# 37/37 [==============================] - 1s 26ms/step - loss: 0.0047 - root_mean_squared_error: 0.0684 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0914
# Epoch 51/120
# 37/37 [==============================] - 1s 29ms/step - loss: 0.0046 - root_mean_squared_error: 0.0675 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0902
# Epoch 52/120
# 37/37 [==============================] - 1s 28ms/step - loss: 0.0049 - root_mean_squared_error: 0.0701 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0910
# Epoch 53/120
# 37/37 [==============================] - 1s 29ms/step - loss: 0.0046 - root_mean_squared_error: 0.0680 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0919
# Epoch 54/120
# 37/37 [==============================] - 1s 27ms/step - loss: 0.0047 - root_mean_squared_error: 0.0686 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0923
# Epoch 55/120
# 37/37 [==============================] - 1s 27ms/step - loss: 0.0046 - root_mean_squared_error: 0.0677 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0908
# Epoch 56/120
# 37/37 [==============================] - 1s 27ms/step - loss: 0.0046 - root_mean_squared_error: 0.0677 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0876
# Epoch 57/120
# 37/37 [==============================] - 1s 26ms/step - loss: 0.0048 - root_mean_squared_error: 0.0691 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0993
# Epoch 58/120
# 37/37 [==============================] - 1s 26ms/step - loss: 0.0050 - root_mean_squared_error: 0.0710 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0883
# Epoch 59/120
# 37/37 [==============================] - 1s 25ms/step - loss: 0.0045 - root_mean_squared_error: 0.0669 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0964
# Epoch 60/120
# 37/37 [==============================] - 1s 27ms/step - loss: 0.0045 - root_mean_squared_error: 0.0673 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0888
# Epoch 61/120
# 37/37 [==============================] - 1s 26ms/step - loss: 0.0048 - root_mean_squared_error: 0.0695 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0921
# Epoch 62/120
# 37/37 [==============================] - 1s 27ms/step - loss: 0.0049 - root_mean_squared_error: 0.0701 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1048
# Epoch 63/120
# 37/37 [==============================] - 1s 27ms/step - loss: 0.0048 - root_mean_squared_error: 0.0696 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0927
# Epoch 64/120
# 37/37 [==============================] - 1s 28ms/step - loss: 0.0045 - root_mean_squared_error: 0.0674 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0918
# Epoch 65/120
# 37/37 [==============================] - 1s 28ms/step - loss: 0.0044 - root_mean_squared_error: 0.0665 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0889
# Epoch 66/120
# 37/37 [==============================] - 1s 27ms/step - loss: 0.0044 - root_mean_squared_error: 0.0665 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0883

# %%
plot_model_rmse_and_loss(history)

# %%
encoder_decoder = tf.keras.models.load_model('encoder_decoder.h5')

forecast = encoder_decoder.predict(X_test)
encoder_decoder_forecast = scaler_y.inverse_transform(forecast)

rmse_encoder_decoder = sqrt(mean_squared_error(y_test_inv, 
                                               encoder_decoder_forecast))
print('RMSE of day ahead power demand Encoder-Decoder forecast: {}'
      .format(round(rmse_encoder_decoder, 3)))
# Out:
# 6/6 [==============================] - 0s 9ms/step
# RMSE of day ahead power demand Encoder-Decoder forecast: 11.849

# %%
# Create arrays for the x-axis (dates)
dates_true = merged_df.index[:1559]
dates_forecasted = merged_df.index[1368:1529]
dates_unseen = merged_df.index[1529:1559]

X_test2 = X[1530:1558,:].reshape(1,28,4)

multivariate_lstm = tf.keras.models.load_model('multivariate_lstm.h5')

forecast_unseen = multivariate_lstm.predict(X_test2)
lstm_forecast_unseen = scaler_y.inverse_transform(forecast_unseen)


# Extend the index to add one more day for unseen predictions
last_date = merged_df.index[-1]
future_date = last_date + pd.DateOffset(days=1)
extended_index = merged_df.index.append(pd.Index([future_date]))

import matplotlib.pyplot as plt

# Assuming merged_df is your DataFrame with the date column set as the index
true_values = merged_df['Energy Required (MU)'].values
 # Replace X_test with your test data



# Plotting the true values and forecasted values
plt.figure(figsize=(20, 6))
plt.plot(dates_true, true_values[:1559], label='True Values')
plt.plot(dates_forecasted,encoder_decoder_forecast, label='Forecasted Values')  # Adjust the number of forecasted values
plt.xlabel('Date')
plt.ylabel('Energy Demand')
plt.title('True vs. Forecasted Energy Demand')
plt.legend()

'''# Adding another plot for unseen predictions
plt.figure(figsize=(12, 6))
plt.plot(dates_unseen, forecasted_values[161:], label='Unseen Predictions')  # Adjust the number of forecasted values
plt.xlabel('Date')
plt.ylabel('Energy Demand')
plt.title('Unseen Predictions')
plt.legend()'''

plt.show()
# Out:
# 1/1 [==============================] - 0s 397ms/step

# %%
import pandas as pd
import datetime

# Function to predict the next demand based on past twenty-eight values
def predict_demand(input_date, df):
    # Convert the input date to datetime object
    input_date = datetime.datetime.strptime(input_date, '%d-%B-%Y')

    # Check if the input date is within the valid range (4 March 2023 to 4 July 2023)
    valid_start_date = datetime.datetime(2023, 4, 4)
    valid_end_date = datetime.datetime(2023, 5, 4)
    if input_date < valid_start_date or input_date > valid_end_date:
        print("Invalid input date. Please enter a date between 4 March 2023 and 4 July 2023.")
        return None

    # Get the past twenty-eight dates from the input date
    past_dates = [input_date - datetime.timedelta(days=i) for i in range(1, 29)]
    print(len(past_dates))
    # Retrieve the corresponding demand values for the past dates from your dataframe
    past_demand_values = merged_df.loc[past_dates]

    # Prepare the input data for your time series model using the past demand values
    input_data = past_demand_values.values.flatten()
    
    # TODO: Use your time series model to predict the next demand based on the input data
    input_data = input_data.reshape(1, past_history,n_features)
    print(input_data.shape)
    model =tf.keras.models.load_model('multivariate_lstm.h5')
    predicted_demand = model.predict(input_data)
        # Determine the date for which the demand is being predicted
    predicted_date = input_date + datetime.timedelta(days=1) 
    # TODO: Return the predicted demand for the next day
    return predicted_demand,predicted_date

# Example usage
# Assuming your dataframe is named 'df' with dates as the index
input_date = input("Enter a date (DD-Month-YYYY): ")
predicted_demand, predicted_date = predict_demand(input_date, merged_df)
print("Predicted demand for", predicted_date.strftime("%d-%B-%Y") + ":", predicted_demand)
# Out:
# Enter a date (DD-Month-YYYY):  04-April-2023
# 28
# (1, 28, 4)
# 1/1 [==============================] - 0s 428ms/step
# Predicted demand for 05-April-2023: [[10.478439]]

# %% [markdown]
# # **GluonTS**

# %%
# !pip install mxnet
# !pip install gluonts

# %%
from gluonts.dataset.pandas import PandasDataset
from gluonts.dataset.split import split
from gluonts.torch import DeepAREstimator
